# %% [markdown]
# goal:
#
# - use librosa on 1000 audio files and/or 50 class folders minimum
# - store information in a dataframe (excluding actual file data for now)
#   - folder name, file name, sampling rate, data length, file length, file size(?)

# %%
import pandas as pd
import numpy as np
import random
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchaudio
import copy
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

from tqdm import tqdm
from IPython.display import Audio

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from imblearn.over_sampling import RandomOverSampler

from math import floor

import sys

# %%
# experimental parameters for model training, for simple configuration in a single cell.
# very useful for reporting spreadsheet

folder_key = {}

split_interval_secs = 2
split_length = 10000000000000 # absurd number for future use
sample_rate = 32000

variance_threshold = 0.2
mean_threshold = 5

total_folders = 50
min_rating = 5.0
max_files_per_folder = 0

sampling_technique = "median"

test_size = 0.2

epochs = 500
batch_size = 512
dropout_rate = 0.5
learning_rate = 0.001
momentum = 0
experimental = False
experimental_counter_limit = 10
save_best_to_file = True

# %%
def reset_seed():
    torch.manual_seed(1368)
    random.seed(1368)
    np.random.seed(1368)

reset_seed()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i in range(torch.cuda.device_count()):
   print(torch.cuda.get_device_properties(i).total_memory)

print(device)
print(torch.cuda.get_device_name())
# Out:
# 85100068864
# cuda
# NVIDIA A100 80GB PCIe

# %%
def get_random_folders_filtered(base_dir: str, split_interval_secs: float, sample_rate: int = 32000, total_folders: int = 50, max_files_per_folder: int = -1, min_rating: float = 4.0):
    global split_length, folder_key
    # base_dir: directory of all the audio file folders
    # split_interval_secs: the length of each sound clip when split up in a file.
    #   - final dataframe will not contain any sound clips over/under this length
    # sample_rate: sample rate of sound clips in hz
    # total_folders: total folders to iterate through the files, given range of files per folder
    # min_files_per_folder: minimum files to exist in the folder
    # max_files_per_folder: maximum files to use inside the folder

    # get the list of valid folders and files to analyse
    folder_key = {}

    folders = []
    valid_folders = set()
    valid_files = set([l.replace("\n", "") for l in open(f"rating_thresholds_at_least_10_classes/min_rating_{int(min_rating * 2)}.txt").readlines()])
    for f in valid_files: valid_folders.add(f.split("/")[0])
    for folder in [line.replace("\n", "") for line in open("folder_order.txt").readlines()]:
        if folder in valid_folders:
            folders.append(folder)

    folder_count = 0

    # if there are less folders than those specified, view all folders instead of given amount
    total_folders = min(len(folders), total_folders)

    rows = []
    
    for folder in folders:
        folder_path = base_dir + folder + "/"
        valid_folder_files = []
        # only iterate through the valid audio files
        for file in os.listdir(folder_path):
            if folder + "/" + file in valid_files:
                valid_folder_files.append(folder_path + file)
        random.shuffle(valid_folder_files)

        if max_files_per_folder > 0:
            valid_folder_files = valid_folder_files[:min(max_files_per_folder, len(valid_folder_files))]

        # iterate through each file in the folder
        for file_path in (progress_bar := tqdm(valid_folder_files)):
            # load file data and resample to sample_rate if necessary
            file_data, file_sample_rate_hz = torchaudio.load(uri=file_path, channels_first=True)
            if file_sample_rate_hz != sample_rate:
                file_data = torchaudio.functional.resample(file_data, orig_freq=file_sample_rate_hz, new_freq=sample_rate)

            # convert all audio into mono (1 channel) if audio is stereo (2 channels)
            if file_data.shape[0] == 2:
                file_data = file_data.mean(dim=0)
            else:
                file_data = file_data.flatten()

            # get total number of X second splits
            total_splits = floor(len(file_data) / int(sample_rate * split_interval_secs))
            
            # convert file data into mel-spectrogram fourier transform for feeding into CNN
            n_fft = 1024

            mel_spec_transform = torchaudio.transforms.MelSpectrogram(sample_rate = sample_rate, power=2, n_fft=n_fft)
            amp_to_db_transform = torchaudio.transforms.AmplitudeToDB(stype="amplitude", top_db=80)
            mel_spec_data_db = amp_to_db_transform(mel_spec_transform(file_data))
            
            # if file is at least X seconds.
            if total_splits >= 1:
                split_length = min(mel_spec_data_db.shape[1] // total_splits, split_length)
                mel_spec_splits = np.arange(0, mel_spec_data_db.shape[1], split_length)
                for i in range(len(mel_spec_splits) - 1):
                    start = mel_spec_splits[i]
                    end = mel_spec_splits[i + 1]

                    mel_spec_split = mel_spec_data_db[:, start:end]

                    row = {}
                    row["folder"] = folder
                    row["file"] = file_path.split("/")[-1]
                    row["mel_spec"] = mel_spec_split
                    row["mel_spec_shape"] = mel_spec_split.shape

                    # determine and filter for "silence":
                    var = torch.var(mel_spec_split)
                    mean = torch.mean(mel_spec_split)

                    if not (var <= variance_threshold):
                        rows.append(row)
                        

                folder_key[folder_count] = folder
            
            progress_bar.set_description(f"Folder {folder_count + 1}/{total_folders} - {folder}")

        # end loop if total_folders has been reached
        folder_count += 1
        if folder_count >= total_folders: break

    # trim the ends of some mel spectrograms because of stupid floating point nonsense
    for row in rows:
        if row["mel_spec_shape"][1] != split_length:
            row["mel_spec"] = row["mel_spec"][:, :split_length]
            row["mel_spec_shape"] = row["mel_spec"].shape

    return pd.DataFrame(rows)

# %%
base_dir = "/mnt/lustre/peprmint/train_audio/"
#base_dir = "../../datasets/birdsongs-combined/train_audio/"

reset_seed()

folder_df = get_random_folders_filtered(
    base_dir, 
    split_interval_secs=split_interval_secs, 
    sample_rate=sample_rate,
    total_folders=total_folders,
    min_rating=min_rating,
    max_files_per_folder=max_files_per_folder
)
# Out:
# Folder 1/50 - dowwoo: 100%|██████████| 27/27 [00:01<00:00, 25.85it/s]
# Folder 2/50 - rerswa1: 100%|██████████| 67/67 [00:02<00:00, 32.53it/s]
# Folder 3/50 - cobtan1: 100%|██████████| 26/26 [00:01<00:00, 20.86it/s]
# Folder 4/50 - barswa: 100%|██████████| 232/232 [00:09<00:00, 23.82it/s]
# Folder 5/50 - indbun: 100%|██████████| 40/40 [00:02<00:00, 16.51it/s]
# Folder 6/50 - comloo: 100%|██████████| 10/10 [00:00<00:00, 18.20it/s]
# Folder 7/50 - mitpar: 100%|██████████| 14/14 [00:01<00:00, 11.42it/s]
# Folder 8/50 - blhpar1: 100%|██████████| 31/31 [00:00<00:00, 35.97it/s]
# Folder 9/50 - amepip: 100%|██████████| 24/24 [00:00<00:00, 40.75it/s]
# Folder 10/50 - brnjay: 100%|██████████| 23/23 [00:00<00:00, 23.09it/s]
# Folder 11/50 - sheowl: 100%|██████████| 22/22 [00:01<00:00, 12.85it/s]
# Folder 12/50 - peflov: 100%|██████████| 13/13 [00:00<00:00, 17.53it/s]
# Folder 13/50 - zebdov: 100%|██████████| 12/12 [00:00<00:00, 24.91it/s]
# Folder 14/50 - yehcar1: 100%|██████████| 36/36 [00:01<00:00, 26.16it/s]
# Folder 15/50 - cubthr: 100%|██████████| 32/32 [00:02<00:00, 14.59it/s]
# Folder 16/50 - amtspa:  56%|█████▋    | 9/16 [00:00<00:00, 19.60it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 16/50 - amtspa:  56%|█████▋    | 9/16 [00:00<00:00, 19.60it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 16/50 - amtspa: 100%|██████████| 16/16 [00:00<00:00, 26.86it/s]
# Folder 17/50 - spotow:  30%|███       | 39/128 [00:02<00:05, 17.35it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 17/50 - spotow: 100%|██████████| 128/128 [00:07<00:00, 17.91it/s]
# Folder 18/50 - buwwar: 100%|██████████| 11/11 [00:01<00:00,  9.61it/s]
# Folder 19/50 - insowl1: 100%|██████████| 11/11 [00:00<00:00, 29.32it/s]
# Folder 20/50 - annhum:  58%|█████▊    | 14/24 [00:00<00:00, 15.87it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 20/50 - annhum: 100%|██████████| 24/24 [00:01<00:00, 19.72it/s]
# Folder 21/50 - bkskit1: 100%|██████████| 67/67 [00:03<00:00, 21.13it/s]
# Folder 22/50 - bkbmag1: 100%|██████████| 13/13 [00:00<00:00, 17.20it/s]
# Folder 23/50 - litegr: 100%|██████████| 127/127 [00:02<00:00, 59.22it/s]
# Folder 24/50 - verdin: 100%|██████████| 31/31 [00:01<00:00, 18.51it/s]
# Folder 25/50 - comyel: 100%|██████████| 78/78 [00:04<00:00, 18.58it/s]
# Folder 26/50 - brubru1: 100%|██████████| 10/10 [00:00<00:00, 40.85it/s]
# Folder 27/50 - blkfra: 100%|██████████| 13/13 [00:00<00:00, 25.33it/s]
# Folder 28/50 - combuz1: 100%|██████████| 130/130 [00:05<00:00, 25.08it/s]
# Folder 29/50 - whiwre1: 100%|██████████| 41/41 [00:01<00:00, 25.63it/s]
# Folder 30/50 - yebsap: 100%|██████████| 14/14 [00:00<00:00, 22.89it/s]
# Folder 31/50 - leater1: 100%|██████████| 44/44 [00:01<00:00, 31.91it/s]
# Folder 32/50 - piebus1: 100%|██████████| 21/21 [00:00<00:00, 39.03it/s]
# Folder 33/50 - yehbla: 100%|██████████| 23/23 [00:01<00:00, 13.36it/s]
# Folder 34/50 - royter1: 100%|██████████| 21/21 [00:00<00:00, 24.67it/s]
# Folder 35/50 - lotduc: 100%|██████████| 20/20 [00:00<00:00, 35.12it/s]
# Folder 36/50 - scbwre1: 100%|██████████| 31/31 [00:01<00:00, 17.21it/s]
# Folder 37/50 - banswa:  68%|██████▊   | 26/38 [00:03<00:01,  7.28it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 37/50 - banswa: 100%|██████████| 38/38 [00:05<00:00,  7.55it/s]
# Folder 38/50 - logshr:   5%|▌         | 2/38 [00:00<00:02, 16.19it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 38/50 - logshr: 100%|██████████| 38/38 [00:03<00:00, 12.62it/s]
# Folder 39/50 - combul2: 100%|██████████| 69/69 [00:03<00:00, 19.06it/s]
# Folder 40/50 - brncre:   0%|          | 0/34 [00:00<?, ?it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 40/50 - brncre: 100%|██████████| 34/34 [00:01<00:00, 17.52it/s]
# Folder 41/50 - whbman1: 100%|██████████| 33/33 [00:01<00:00, 24.60it/s]
# Folder 42/50 - compau: 100%|██████████| 105/105 [00:05<00:00, 20.43it/s]
# Folder 43/50 - pirfly1: 100%|██████████| 35/35 [00:01<00:00, 22.74it/s]
# Folder 44/50 - ocbfly1: 100%|██████████| 10/10 [00:00<00:00, 18.82it/s]
# Folder 45/50 - oliwoo1: 100%|██████████| 42/42 [00:01<00:00, 27.97it/s]
# Folder 46/50 - eucdov:  59%|█████▉    | 62/105 [00:02<00:01, 28.16it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 46/50 - eucdov: 100%|██████████| 105/105 [00:03<00:00, 29.57it/s]
# Folder 47/50 - phaino: 100%|██████████| 12/12 [00:01<00:00, 11.20it/s]
# Folder 48/50 - mawthr1: 100%|██████████| 18/18 [00:00<00:00, 22.94it/s]
# Folder 49/50 - redcro: 100%|██████████| 284/284 [00:15<00:00, 18.87it/s]
# Folder 50/50 - grycat: 100%|██████████| 56/56 [00:04<00:00, 13.68it/s]

# %%
folder_df["mel_spec_shape"].value_counts()
# Out:
# mel_spec_shape
# (128, 125)    49431
# Name: count, dtype: int64

# %%
folder_df["folder"].value_counts()
# Out:
# folder
# redcro     6678
# barswa     4488
# combuz1    2718
# banswa     2617
# spotow     2592
# compau     2436
# grycat     1956
# bkskit1    1868
# combul2    1838
# eucdov     1751
# comyel     1511
# logshr     1390
# rerswa1    1026
# litegr      931
# indbun      898
# cubthr      843
# scbwre1     807
# yehbla      741
# pirfly1     713
# whiwre1     655
# verdin      629
# whbman1     592
# oliwoo1     578
# cobtan1     573
# leater1     543
# yehcar1     530
# brncre      526
# mitpar      489
# brnjay      481
# dowwoo      437
# annhum      431
# phaino      402
# blhpar1     399
# buwwar      391
# mawthr1     391
# sheowl      378
# peflov      363
# bkbmag1     355
# royter1     353
# piebus1     256
# ocbfly1     245
# amtspa      224
# lotduc      212
# insowl1     209
# yebsap      206
# comloo      188
# amepip      179
# zebdov      171
# blkfra      142
# brubru1     101
# Name: count, dtype: int64

# %%
print("sound clips BEFORE any sampling:", len(folder_df))
# Out:
# sound clips BEFORE any sampling: 49431

# %%
len(folder_df["folder"].unique())
# Out:
# 50

# %%
folder_df["folder"].value_counts().plot.bar(title="Value counts before over/under sampling.")
# Out:
# <Axes: title={'center': 'Value counts before over/under sampling.'}, xlabel='folder'>

# %%
# apply random undersampling OR oversampling

reset_seed()

if sampling_technique == "under":
    # random "naive" undersampling
    # delete random rows from all classes except minority class(es)
    min_folder_count = min(folder_df["folder"].value_counts())

    indices_to_keep = np.array([])

    for f in folder_df["folder"].unique():
        indices_to_keep = np.concat([np.random.choice(folder_df[folder_df["folder"] == f].index, size=min_folder_count), indices_to_keep])

    folder_df = folder_df.loc[indices_to_keep]
    folder_df.reset_index(drop=True, inplace=True)

if sampling_technique == "over":
    ros = RandomOverSampler(random_state=1368)

    # print how much each class will increase by (relative to its current size)
    max_folder = max(folder_df["folder"].value_counts())
    for folder, count in folder_df["folder"].value_counts().sort_values(ascending=True).items():
        print(f"{folder} will increase by {round((max_folder / count - 1) * 100, 2)}%")

    folder_df = pd.concat(ros.fit_resample(folder_df.drop("folder", axis=1), folder_df["folder"]), axis=1)
    # moves "folder" to other side of df but shouldn't affect anything

if sampling_technique == "median":
    # take the median value of folder counts
    # under sample all above the median
    # over smaple all below the median

    ros = RandomOverSampler(random_state=1368)
    median_folder_count = round(folder_df["folder"].value_counts().median())
    indices_to_keep = np.array([])

    print("median:", median_folder_count)

    for f in folder_df["folder"].unique():
        folder_length = len(folder_df[folder_df["folder"] == f])
        if folder_length > median_folder_count:
            indices_to_keep = np.concat([np.random.choice(folder_df[folder_df["folder"] == f].index, size=median_folder_count), indices_to_keep])
        else:
            indices_to_keep = np.concat([folder_df[folder_df["folder"] == f].index, indices_to_keep])
        
    folder_df = folder_df.loc[indices_to_keep]
    folder_df.reset_index(drop=True, inplace=True)
    
    folder_df = pd.concat(ros.fit_resample(folder_df.drop("folder", axis=1), folder_df["folder"]), axis=1)
# Out:
# median: 536

# %%
folder_df["folder"].value_counts().plot.bar(title=f"Value counts after {sampling_technique} sampling.")
# Out:
# <Axes: title={'center': 'Value counts after median sampling.'}, xlabel='folder'>

# %%
print("sound clips AFTER sampling:", len(folder_df))
# Out:
# sound clips AFTER sampling: 26800

# %%
# plot 5 random mel spectrograms
# checks for consistency in scaling and whatnot

reset_seed()

sample_spec_indices = random.sample(folder_df.index.tolist(), k=3)

for i in sample_spec_indices:
    row = folder_df.iloc[i]
    
    print(row["mel_spec_shape"])
    
    plt.figure()
    plt.imshow(row["mel_spec"])
    plt.title(f"Mel-Spectrogram of {'/'.join(row['file'].split('/')[-2:])}")
    plt.colorbar(format='%+2.0f dB')
    plt.show()

del row
# Out:
# torch.Size([128, 125])
# torch.Size([128, 125])
# torch.Size([128, 125])

# %%
# input shape needs to be AxBxCxD
# A = list of files
# B = depth of each one (currently just 1, as it only contains 1 value. if colours are used then maybe up it to 3)
# CxD = input width/height (128x626 etc)

x = torch.from_numpy(np.stack(folder_df["mel_spec"].values))
x = x.reshape(x.shape[0], 1, x.shape[1], x.shape[2])
x = x.to(device)

le = LabelEncoder()
y = torch.LongTensor(le.fit_transform(folder_df["folder"]))
y = y.to(device)

# %%
reset_seed()

x_train, x_test, y_train, y_test = train_test_split(x, y, shuffle=True, test_size=test_size, random_state=1368)

del x, y

# %%
# create machine learning model.

class TestModel(nn.Module):
    global folder_df

    def __init__(self, input_shape: torch.Size, dropout_rate: float = 0):
        super().__init__()

        total_output_classes = len(folder_df["folder"].unique())

        # input shape should be some list/tuple of length 4
        if len(input_shape) != 4: return Exception("Input shape is not AxBxCxD.")
        
        A = input_shape[0]
        B = input_shape[1]
        C = input_shape[2]
        D = input_shape[3]

        self.conv1 = nn.Conv2d(in_channels=B, out_channels=10, kernel_size=(3, 3))
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2)
        self.drop1 = nn.Dropout(p=dropout_rate)
        self.conv2 = nn.Conv2d(in_channels=10, out_channels=10, kernel_size=(3, 3))
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        self.drop2 = nn.Dropout(p=dropout_rate)
        self.flat = nn.Flatten()

        flatten_nodes = 10 * ((((C - 2) // 2) - 2) // 2) * ((((D - 2) // 2) - 2) // 2)
        
        self.norm = nn.BatchNorm1d(num_features=flatten_nodes)
        self.linear1 = nn.Linear(in_features=flatten_nodes, out_features=1024)
        self.linear2 = nn.Linear(in_features=1024, out_features=512)
        self.linear3 = nn.Linear(in_features=512, out_features=128) 
        self.output = nn.Linear(in_features=128, out_features=total_output_classes)

    def forward(self, x):
        # define calculations here
        x = self.relu1(self.conv1(x))
        x = self.pool1(x)
        x = self.drop1(x)
        x = self.relu2(self.conv2(x))
        x = self.pool2(x)
        x = self.drop2(x)
        x = self.flat(x)
        x = self.norm(x)
        x = self.linear1(x)
        x = self.linear2(x)
        x = self.linear3(x)
        x = self.output(x)

        return x

# %%
# model: the model to train
# loss_fn: the loss function to update weights
# optimizer: the optimiser function to affect rate of change
# epochs: number of epochs to train the model over
# batch_size: samples to train x_train and y_train to avoid memory issues
# save_best_to_file: save model with highest test accuracy to models/ folder.
# experimental: whether to end training after 5 consecutive runs of no higher test accuracy.
#       - training ends when either [epochs] epochs have been run, *OR* if 5 consecutive runs do not improve test accuracy from previous best.

def train_model(model, loss_fn, optimizer, epochs, batch_size, save_best_to_file = False, experimental = False):
    global x_train, y_train
    batch_indices = np.linspace(0, len(x_train), int(len(x_train) / batch_size), dtype="int")

    train_loss_hist = []
    train_acc_hist = []
    test_acc_hist = []

    best_test_acc = 0
    best_model = None

    experimental_counter = 0

    for epoch in range(1, epochs + 1):
        model.train()

        train_acc = 0
        
        for i in range(len(batch_indices) - 1):
            start_index = batch_indices[i]
            stop_index = batch_indices[i + 1]

            x_batch = x_train[start_index:stop_index]
            y_batch = y_train[start_index:stop_index]

            x_batch, y_batch = shuffle(x_batch, y_batch)

            y_pred = model(x_batch)
            loss = loss_fn(y_pred, y_batch)
            train_acc += sum(torch.argmax(y_pred, dim=1) == y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_acc = train_acc * 100 / len(y_train)

        model.eval()
        test_acc = sum(torch.argmax(model(x_test), dim=1) == y_test) * 100 / len(y_test)

        print(f"Epoch {epoch}: train loss = {loss:.04f}, train acc = {train_acc:.02f}%, test acc = {test_acc:.02f}% {"!!" if test_acc > best_test_acc else ""}")

        train_loss_hist.append(float(loss.cpu().detach().numpy()))
        train_acc_hist.append(float(train_acc.cpu().detach().numpy()))
        test_acc_hist.append(float(test_acc.cpu().detach().numpy()))

        if experimental:
            experimental_counter += 1

        if test_acc > best_test_acc:
            experimental_counter = 0
            best_test_acc = test_acc
            
            # overwrite best model with new best model
            best_model = copy.deepcopy(model.state_dict())

        if experimental_counter == experimental_counter_limit:
            print(f"Experimental Mode ended the training early, as the testing accuracy had not increased over {experimental_counter_limit} consecutive epochs.")
            break
        
    if save_best_to_file:
        model_save_path = "models/"
        if not os.path.exists(model_save_path): os.mkdir(model_save_path)
        file_number = len(os.listdir(model_save_path)) + 1
        file_name = f"best_model_{file_number:>03}"
        best_model_path = model_save_path + file_name + ".pth"

        torch.save(best_model, best_model_path)

    plt.figure(figsize=(12,8))
    pd.Series(train_acc_hist).plot.line(label="Train", color="blue")
    pd.Series(test_acc_hist).plot.line(label="Test", color="red")
    plt.legend()
    plt.ylim((0, 100))
    plt.yticks(np.arange(0, 101, 10))
    plt.title(f"Convolutional Neural Network on {len(folder_df)} sound clips over {len(folder_df["folder"].unique())} folders.")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.grid(axis="y")
    plt.show()

    return train_loss_hist, train_acc_hist, test_acc_hist, best_model

# %%
# to avoid extreme overfitting:
# - dropout rate between 0.2-0.5 seems good
# - learning rate around 0.001 provides best training rate without overfitting
# - train in larger batches, 64 upwards seems good
# - most seem to plateau around 200 epochs, maybe reduce to reduce total training time

reset_seed()

model = TestModel(input_shape=x_train.shape, dropout_rate=dropout_rate)
model = model.to(device)
loss_fn = nn.CrossEntropyLoss() # since we are classifying.
loss_fn = loss_fn.to(device)
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate) # adam has no momentum, but DOES have weight decay

print(sum(p.numel() for p in model.parameters() if p.requires_grad))

train_loss_hist, train_acc_hist, test_acc_hist, best_model = train_model(model, loss_fn, optimizer, epochs, batch_size, save_best_to_file=save_best_to_file, experimental=experimental)
# Out:
# 9525148
# Epoch 1: train loss = 2.9361, train acc = 16.46%, test acc = 13.56% !!
# Epoch 2: train loss = 2.4230, train acc = 32.16%, test acc = 23.54% !!
# Epoch 3: train loss = 2.2344, train acc = 40.69%, test acc = 33.34% !!
# Epoch 4: train loss = 1.9975, train acc = 46.68%, test acc = 44.48% !!
# Epoch 5: train loss = 1.9650, train acc = 50.67%, test acc = 48.60% !!
# Epoch 6: train loss = 1.7204, train acc = 54.19%, test acc = 50.45% !!
# Epoch 7: train loss = 1.6618, train acc = 56.92%, test acc = 54.96% !!
# Epoch 8: train loss = 1.6433, train acc = 59.57%, test acc = 54.93%
# Epoch 9: train loss = 1.5507, train acc = 61.51%, test acc = 57.67% !!
# Epoch 10: train loss = 1.4456, train acc = 62.74%, test acc = 58.60% !!
# Epoch 11: train loss = 1.4245, train acc = 64.36%, test acc = 59.79% !!
# Epoch 12: train loss = 1.3044, train acc = 65.27%, test acc = 61.27% !!
# Epoch 13: train loss = 1.2748, train acc = 66.64%, test acc = 62.80% !!
# Epoch 14: train loss = 1.2319, train acc = 68.40%, test acc = 63.73% !!
# Epoch 15: train loss = 1.1446, train acc = 69.29%, test acc = 64.38% !!
# Epoch 16: train loss = 1.2269, train acc = 69.84%, test acc = 64.59% !!
# Epoch 17: train loss = 1.0415, train acc = 70.47%, test acc = 66.19% !!
# Epoch 18: train loss = 1.0856, train acc = 71.61%, test acc = 66.70% !!
# Epoch 19: train loss = 1.0653, train acc = 72.22%, test acc = 65.15%
# Epoch 20: train loss = 1.0812, train acc = 73.15%, test acc = 66.62%
# Epoch 21: train loss = 1.0002, train acc = 73.71%, test acc = 67.56% !!
# Epoch 22: train loss = 1.1496, train acc = 73.82%, test acc = 67.87% !!
# Epoch 23: train loss = 0.8668, train acc = 74.31%, test acc = 67.59%
# Epoch 24: train loss = 1.0528, train acc = 74.95%, test acc = 68.90% !!
# Epoch 25: train loss = 0.9262, train acc = 75.33%, test acc = 68.81%
# Epoch 26: train loss = 0.9684, train acc = 75.61%, test acc = 69.22% !!
# Epoch 27: train loss = 0.9119, train acc = 75.52%, test acc = 68.73%
# Epoch 28: train loss = 0.8144, train acc = 76.39%, test acc = 69.85% !!
# Epoch 29: train loss = 0.9011, train acc = 76.59%, test acc = 69.79%
# Epoch 30: train loss = 0.8921, train acc = 77.67%, test acc = 68.06%
# Epoch 31: train loss = 0.8784, train acc = 78.16%, test acc = 71.08% !!
# Epoch 32: train loss = 0.8284, train acc = 78.09%, test acc = 69.87%
# Epoch 33: train loss = 0.8443, train acc = 77.97%, test acc = 70.88%
# Epoch 34: train loss = 0.7241, train acc = 79.32%, test acc = 71.08%
# Epoch 35: train loss = 0.8225, train acc = 79.01%, test acc = 71.31% !!
# Epoch 36: train loss = 0.7982, train acc = 78.73%, test acc = 70.63%
# Epoch 37: train loss = 0.7885, train acc = 79.22%, test acc = 70.09%
# Epoch 38: train loss = 0.7995, train acc = 79.82%, test acc = 70.88%
# Epoch 39: train loss = 0.7695, train acc = 79.48%, test acc = 70.58%
# Epoch 40: train loss = 0.7830, train acc = 79.64%, test acc = 70.32%
# Epoch 41: train loss = 0.6993, train acc = 80.27%, test acc = 70.80%
# Epoch 42: train loss = 0.7196, train acc = 80.38%, test acc = 69.85%
# Epoch 43: train loss = 0.7277, train acc = 80.72%, test acc = 70.82%
# Epoch 44: train loss = 0.7005, train acc = 80.61%, test acc = 71.08%
# Epoch 45: train loss = 0.7226, train acc = 80.86%, test acc = 70.86%
# Epoch 46: train loss = 0.7393, train acc = 81.26%, test acc = 70.67%
# Epoch 47: train loss = 0.7132, train acc = 81.31%, test acc = 72.26% !!
# Epoch 48: train loss = 0.7920, train acc = 81.42%, test acc = 71.44%
# Epoch 49: train loss = 0.6320, train acc = 82.12%, test acc = 72.22%
# Epoch 50: train loss = 0.7289, train acc = 82.23%, test acc = 71.36%
# Epoch 51: train loss = 0.7010, train acc = 82.08%, test acc = 72.37% !!
# Epoch 52: train loss = 0.7032, train acc = 82.24%, test acc = 72.56% !!
# Epoch 53: train loss = 0.7057, train acc = 82.75%, test acc = 71.87%
# Epoch 54: train loss = 0.6213, train acc = 82.07%, test acc = 72.87% !!
# Epoch 55: train loss = 0.6376, train acc = 82.63%, test acc = 72.39%
# Epoch 56: train loss = 0.5825, train acc = 82.92%, test acc = 72.63%
# Epoch 57: train loss = 0.5947, train acc = 83.23%, test acc = 72.15%
# Epoch 58: train loss = 0.6959, train acc = 82.78%, test acc = 72.67%
# Epoch 59: train loss = 0.7555, train acc = 82.62%, test acc = 72.37%
# Epoch 60: train loss = 0.6429, train acc = 82.96%, test acc = 72.99% !!
# Epoch 61: train loss = 0.6127, train acc = 83.43%, test acc = 72.46%
# Epoch 62: train loss = 0.6733, train acc = 83.29%, test acc = 72.07%
# Epoch 63: train loss = 0.6215, train acc = 83.28%, test acc = 72.05%
# Epoch 64: train loss = 0.6476, train acc = 83.56%, test acc = 72.41%
# Epoch 65: train loss = 0.6786, train acc = 83.82%, test acc = 72.59%
# Epoch 66: train loss = 0.5810, train acc = 84.04%, test acc = 72.67%
# Epoch 67: train loss = 0.6137, train acc = 83.47%, test acc = 73.56% !!
# Epoch 68: train loss = 0.5368, train acc = 83.76%, test acc = 73.08%
# Epoch 69: train loss = 0.7120, train acc = 83.65%, test acc = 72.67%
# Epoch 70: train loss = 0.5837, train acc = 83.60%, test acc = 73.12%
# Epoch 71: train loss = 0.5509, train acc = 83.78%, test acc = 72.67%
# Epoch 72: train loss = 0.5952, train acc = 84.54%, test acc = 73.04%
# Epoch 73: train loss = 0.5213, train acc = 84.69%, test acc = 72.20%
# Epoch 74: train loss = 0.6720, train acc = 84.10%, test acc = 73.53%
# Epoch 75: train loss = 0.6026, train acc = 84.05%, test acc = 73.06%
# Epoch 76: train loss = 0.5456, train acc = 84.50%, test acc = 72.76%
# Epoch 77: train loss = 0.5771, train acc = 85.07%, test acc = 73.43%
# Epoch 78: train loss = 0.6261, train acc = 84.09%, test acc = 72.99%
# Epoch 79: train loss = 0.5395, train acc = 84.49%, test acc = 73.45%
# Epoch 80: train loss = 0.5455, train acc = 84.86%, test acc = 72.85%
# Epoch 81: train loss = 0.6162, train acc = 84.72%, test acc = 72.33%
# Epoch 82: train loss = 0.5679, train acc = 84.97%, test acc = 73.10%
# Epoch 83: train loss = 0.5712, train acc = 85.40%, test acc = 73.28%
# Epoch 84: train loss = 0.5746, train acc = 84.73%, test acc = 73.60% !!
# Epoch 85: train loss = 0.6321, train acc = 84.96%, test acc = 73.25%
# Epoch 86: train loss = 0.4808, train acc = 85.54%, test acc = 73.90% !!
# Epoch 87: train loss = 0.4728, train acc = 85.96%, test acc = 73.75%
# Epoch 88: train loss = 0.5363, train acc = 85.86%, test acc = 73.90%
# Epoch 89: train loss = 0.4085, train acc = 85.51%, test acc = 72.93%
# Epoch 90: train loss = 0.6402, train acc = 85.45%, test acc = 74.37% !!
# Epoch 91: train loss = 0.5754, train acc = 85.50%, test acc = 73.43%
# Epoch 92: train loss = 0.4649, train acc = 85.62%, test acc = 72.91%
# Epoch 93: train loss = 0.5316, train acc = 85.76%, test acc = 73.28%
# Epoch 94: train loss = 0.5291, train acc = 86.19%, test acc = 73.79%
# Epoch 95: train loss = 0.5209, train acc = 85.84%, test acc = 73.79%
# Epoch 96: train loss = 0.5448, train acc = 85.34%, test acc = 73.06%
# Epoch 97: train loss = 0.5520, train acc = 84.84%, test acc = 72.93%
# Epoch 98: train loss = 0.5156, train acc = 85.05%, test acc = 73.23%
# Epoch 99: train loss = 0.5406, train acc = 85.49%, test acc = 73.30%
# Epoch 100: train loss = 0.5280, train acc = 85.97%, test acc = 73.62%
# Epoch 101: train loss = 0.4310, train acc = 86.39%, test acc = 73.53%
# Epoch 102: train loss = 0.5258, train acc = 85.75%, test acc = 73.43%
# Epoch 103: train loss = 0.5881, train acc = 85.63%, test acc = 72.93%
# Epoch 104: train loss = 0.5001, train acc = 86.32%, test acc = 73.43%
# Epoch 105: train loss = 0.5282, train acc = 86.34%, test acc = 73.53%
# Epoch 106: train loss = 0.5511, train acc = 86.41%, test acc = 73.62%
# Epoch 107: train loss = 0.5142, train acc = 86.71%, test acc = 73.25%
# Epoch 108: train loss = 0.5130, train acc = 85.80%, test acc = 73.17%
# Epoch 109: train loss = 0.4619, train acc = 85.73%, test acc = 72.74%
# Epoch 110: train loss = 0.6251, train acc = 85.70%, test acc = 74.10%
# Epoch 111: train loss = 0.4751, train acc = 86.59%, test acc = 74.72% !!
# Epoch 112: train loss = 0.5895, train acc = 86.59%, test acc = 73.40%
# Epoch 113: train loss = 0.4681, train acc = 86.23%, test acc = 73.88%
# Epoch 114: train loss = 0.5146, train acc = 86.27%, test acc = 73.66%
# Epoch 115: train loss = 0.5090, train acc = 86.31%, test acc = 72.97%
# Epoch 116: train loss = 0.5426, train acc = 85.62%, test acc = 73.36%
# Epoch 117: train loss = 0.5031, train acc = 86.09%, test acc = 74.55%
# Epoch 118: train loss = 0.4292, train acc = 86.79%, test acc = 73.40%
# Epoch 119: train loss = 0.5334, train acc = 86.77%, test acc = 73.77%
# Epoch 120: train loss = 0.5948, train acc = 87.08%, test acc = 73.17%
# Epoch 121: train loss = 0.5312, train acc = 87.16%, test acc = 74.20%
# Epoch 122: train loss = 0.5446, train acc = 86.72%, test acc = 74.05%
# Epoch 123: train loss = 0.4904, train acc = 86.84%, test acc = 73.84%
# Epoch 124: train loss = 0.4548, train acc = 87.10%, test acc = 73.96%
# Epoch 125: train loss = 0.4389, train acc = 87.34%, test acc = 73.26%
# Epoch 126: train loss = 0.4285, train acc = 87.26%, test acc = 73.41%
# Epoch 127: train loss = 0.4062, train acc = 87.42%, test acc = 73.94%
# Epoch 128: train loss = 0.5341, train acc = 87.24%, test acc = 73.71%
# Epoch 129: train loss = 0.5313, train acc = 87.08%, test acc = 73.69%
# Epoch 130: train loss = 0.5441, train acc = 87.49%, test acc = 73.97%
# Epoch 131: train loss = 0.4279, train acc = 87.02%, test acc = 73.30%
# Epoch 132: train loss = 0.4247, train acc = 87.39%, test acc = 74.37%
# Epoch 133: train loss = 0.4813, train acc = 87.19%, test acc = 73.97%
# Epoch 134: train loss = 0.4576, train acc = 87.61%, test acc = 74.33%
# Epoch 135: train loss = 0.3983, train acc = 87.05%, test acc = 73.38%
# Epoch 136: train loss = 0.5399, train acc = 87.10%, test acc = 73.79%
# Epoch 137: train loss = 0.4518, train acc = 87.05%, test acc = 74.29%
# Epoch 138: train loss = 0.4202, train acc = 87.57%, test acc = 74.22%
# Epoch 139: train loss = 0.3978, train acc = 87.60%, test acc = 74.27%
# Epoch 140: train loss = 0.5245, train acc = 86.77%, test acc = 73.94%
# Epoch 141: train loss = 0.4879, train acc = 87.26%, test acc = 73.25%
# Epoch 142: train loss = 0.5730, train acc = 87.69%, test acc = 73.47%
# Epoch 143: train loss = 0.5284, train acc = 87.76%, test acc = 73.69%
# Epoch 144: train loss = 0.4476, train acc = 87.78%, test acc = 73.02%
# Epoch 145: train loss = 0.4975, train acc = 87.81%, test acc = 73.68%
# Epoch 146: train loss = 0.3419, train acc = 87.78%, test acc = 73.36%
# Epoch 147: train loss = 0.5192, train acc = 87.02%, test acc = 74.01%
# Epoch 148: train loss = 0.3989, train acc = 88.06%, test acc = 73.84%
# Epoch 149: train loss = 0.4937, train acc = 87.96%, test acc = 74.51%
# Epoch 150: train loss = 0.4992, train acc = 87.97%, test acc = 73.99%
# Epoch 151: train loss = 0.4429, train acc = 87.81%, test acc = 73.53%
# Epoch 152: train loss = 0.4714, train acc = 88.14%, test acc = 73.60%
# Epoch 153: train loss = 0.4921, train acc = 88.22%, test acc = 73.64%
# Epoch 154: train loss = 0.3967, train acc = 87.96%, test acc = 73.86%
# Epoch 155: train loss = 0.5088, train acc = 88.31%, test acc = 73.79%
# Epoch 156: train loss = 0.4813, train acc = 88.00%, test acc = 74.18%
# Epoch 157: train loss = 0.4333, train acc = 87.47%, test acc = 73.81%
# Epoch 158: train loss = 0.5632, train acc = 87.65%, test acc = 74.63%
# Epoch 159: train loss = 0.3791, train acc = 87.98%, test acc = 74.24%
# Epoch 160: train loss = 0.4122, train acc = 88.78%, test acc = 73.69%
# Epoch 161: train loss = 0.4411, train acc = 87.70%, test acc = 73.26%
# Epoch 162: train loss = 0.4904, train acc = 87.85%, test acc = 73.92%
# Epoch 163: train loss = 0.5691, train acc = 88.29%, test acc = 74.16%
# Epoch 164: train loss = 0.5493, train acc = 87.79%, test acc = 74.31%
# Epoch 165: train loss = 0.5166, train acc = 87.99%, test acc = 73.62%
# Epoch 166: train loss = 0.3501, train acc = 88.32%, test acc = 73.94%
# Epoch 167: train loss = 0.4662, train acc = 88.14%, test acc = 73.21%
# Epoch 168: train loss = 0.4267, train acc = 87.75%, test acc = 73.79%
# Epoch 169: train loss = 0.4876, train acc = 88.25%, test acc = 73.58%
# Epoch 170: train loss = 0.5169, train acc = 88.24%, test acc = 74.35%
# Epoch 171: train loss = 0.4415, train acc = 87.92%, test acc = 73.96%
# Epoch 172: train loss = 0.4682, train acc = 88.54%, test acc = 74.38%
# Epoch 173: train loss = 0.3999, train acc = 88.15%, test acc = 74.31%
# Epoch 174: train loss = 0.4510, train acc = 88.43%, test acc = 74.09%
# Epoch 175: train loss = 0.5238, train acc = 87.80%, test acc = 73.90%
# Epoch 176: train loss = 0.3691, train acc = 88.46%, test acc = 74.09%
# Epoch 177: train loss = 0.4858, train acc = 88.20%, test acc = 74.18%
# Epoch 178: train loss = 0.4611, train acc = 88.48%, test acc = 73.86%
# Epoch 179: train loss = 0.4702, train acc = 88.19%, test acc = 73.60%
# Epoch 180: train loss = 0.3864, train acc = 88.60%, test acc = 74.33%
# Epoch 181: train loss = 0.3915, train acc = 88.42%, test acc = 73.81%
# Epoch 182: train loss = 0.4777, train acc = 87.96%, test acc = 73.92%
# Epoch 183: train loss = 0.4283, train acc = 88.29%, test acc = 73.79%
# Epoch 184: train loss = 0.5114, train acc = 88.30%, test acc = 74.61%
# Epoch 185: train loss = 0.4125, train acc = 88.77%, test acc = 74.38%
# Epoch 186: train loss = 0.4311, train acc = 88.53%, test acc = 73.97%
# Epoch 187: train loss = 0.3960, train acc = 89.03%, test acc = 74.29%
# Epoch 188: train loss = 0.4394, train acc = 88.76%, test acc = 73.56%
# Epoch 189: train loss = 0.4293, train acc = 88.76%, test acc = 73.84%
# Epoch 190: train loss = 0.4908, train acc = 89.27%, test acc = 73.79%
# Epoch 191: train loss = 0.4470, train acc = 88.44%, test acc = 73.62%
# Epoch 192: train loss = 0.4274, train acc = 88.48%, test acc = 73.77%
# Epoch 193: train loss = 0.5308, train acc = 88.67%, test acc = 72.99%
# Epoch 194: train loss = 0.4200, train acc = 88.59%, test acc = 73.94%
# Epoch 195: train loss = 0.4052, train acc = 88.74%, test acc = 74.38%
# Epoch 196: train loss = 0.4306, train acc = 88.74%, test acc = 74.50%
# Epoch 197: train loss = 0.4537, train acc = 88.93%, test acc = 74.18%
# Epoch 198: train loss = 0.4675, train acc = 89.17%, test acc = 74.33%
# Epoch 199: train loss = 0.4461, train acc = 88.77%, test acc = 73.66%
# Epoch 200: train loss = 0.5411, train acc = 88.04%, test acc = 74.01%
# Epoch 201: train loss = 0.3493, train acc = 88.71%, test acc = 73.86%
# Epoch 202: train loss = 0.3729, train acc = 88.48%, test acc = 74.46%
# Epoch 203: train loss = 0.3612, train acc = 89.10%, test acc = 74.48%
# Epoch 204: train loss = 0.4889, train acc = 88.68%, test acc = 74.10%
# Epoch 205: train loss = 0.3981, train acc = 89.10%, test acc = 73.81%
# Epoch 206: train loss = 0.3633, train acc = 88.91%, test acc = 74.03%
# Epoch 207: train loss = 0.4368, train acc = 88.64%, test acc = 74.55%
# Epoch 208: train loss = 0.5081, train acc = 88.65%, test acc = 74.35%
# Epoch 209: train loss = 0.3977, train acc = 88.82%, test acc = 74.55%
# Epoch 210: train loss = 0.4158, train acc = 89.37%, test acc = 74.59%
# Epoch 211: train loss = 0.3821, train acc = 88.89%, test acc = 74.42%
# Epoch 212: train loss = 0.3991, train acc = 89.05%, test acc = 74.22%
# Epoch 213: train loss = 0.3813, train acc = 89.38%, test acc = 74.57%
# Epoch 214: train loss = 0.4351, train acc = 89.03%, test acc = 73.92%
# Epoch 215: train loss = 0.4219, train acc = 88.84%, test acc = 73.86%
# Epoch 216: train loss = 0.4180, train acc = 88.59%, test acc = 74.68%
# Epoch 217: train loss = 0.4425, train acc = 89.58%, test acc = 75.00% !!
# Epoch 218: train loss = 0.3388, train acc = 89.57%, test acc = 74.38%
# Epoch 219: train loss = 0.4052, train acc = 89.31%, test acc = 74.55%
# Epoch 220: train loss = 0.3792, train acc = 89.43%, test acc = 75.13% !!
# Epoch 221: train loss = 0.4469, train acc = 89.40%, test acc = 74.16%
# Epoch 222: train loss = 0.4329, train acc = 89.42%, test acc = 75.00%
# Epoch 223: train loss = 0.4499, train acc = 88.72%, test acc = 74.81%
# Epoch 224: train loss = 0.4482, train acc = 89.21%, test acc = 74.94%
# Epoch 225: train loss = 0.4504, train acc = 89.11%, test acc = 74.14%
# Epoch 226: train loss = 0.4099, train acc = 89.17%, test acc = 74.03%
# Epoch 227: train loss = 0.4122, train acc = 89.25%, test acc = 74.14%
# Epoch 228: train loss = 0.5369, train acc = 88.60%, test acc = 74.46%
# Epoch 229: train loss = 0.4928, train acc = 88.98%, test acc = 74.72%
# Epoch 230: train loss = 0.4694, train acc = 88.75%, test acc = 74.66%
# Epoch 231: train loss = 0.3621, train acc = 89.10%, test acc = 74.40%
# Epoch 232: train loss = 0.3524, train acc = 89.31%, test acc = 74.98%
# Epoch 233: train loss = 0.4660, train acc = 89.06%, test acc = 73.43%
# Epoch 234: train loss = 0.4624, train acc = 88.86%, test acc = 73.17%
# Epoch 235: train loss = 0.4401, train acc = 88.56%, test acc = 74.22%
# Epoch 236: train loss = 0.4077, train acc = 89.40%, test acc = 74.59%
# Epoch 237: train loss = 0.4163, train acc = 89.35%, test acc = 74.66%
# Epoch 238: train loss = 0.3565, train acc = 89.15%, test acc = 74.66%
# Epoch 239: train loss = 0.3871, train acc = 89.70%, test acc = 74.61%
# Epoch 240: train loss = 0.3715, train acc = 89.60%, test acc = 74.29%
# Epoch 241: train loss = 0.3617, train acc = 89.88%, test acc = 74.72%
# Epoch 242: train loss = 0.3936, train acc = 89.70%, test acc = 74.24%
# Epoch 243: train loss = 0.4437, train acc = 88.77%, test acc = 74.25%
# Epoch 244: train loss = 0.4357, train acc = 88.88%, test acc = 74.65%
# Epoch 245: train loss = 0.4335, train acc = 89.28%, test acc = 74.44%
# Epoch 246: train loss = 0.4041, train acc = 89.04%, test acc = 74.37%
# Epoch 247: train loss = 0.4377, train acc = 89.59%, test acc = 74.53%
# Epoch 248: train loss = 0.3630, train acc = 89.41%, test acc = 74.51%
# Epoch 249: train loss = 0.3585, train acc = 89.34%, test acc = 74.83%
# Epoch 250: train loss = 0.4031, train acc = 89.13%, test acc = 74.93%
# Epoch 251: train loss = 0.3654, train acc = 89.33%, test acc = 75.17% !!
# Epoch 252: train loss = 0.3565, train acc = 89.48%, test acc = 74.59%
# Epoch 253: train loss = 0.4085, train acc = 89.71%, test acc = 74.48%
# Epoch 254: train loss = 0.3386, train acc = 89.55%, test acc = 74.65%
# Epoch 255: train loss = 0.3983, train acc = 89.98%, test acc = 74.31%
# Epoch 256: train loss = 0.4240, train acc = 89.25%, test acc = 74.40%
# Epoch 257: train loss = 0.4018, train acc = 89.50%, test acc = 74.09%
# Epoch 258: train loss = 0.4697, train acc = 89.58%, test acc = 74.18%
# Epoch 259: train loss = 0.4191, train acc = 90.06%, test acc = 74.81%
# Epoch 260: train loss = 0.4100, train acc = 89.93%, test acc = 74.40%
# Epoch 261: train loss = 0.3810, train acc = 89.79%, test acc = 74.38%
# Epoch 262: train loss = 0.3828, train acc = 89.96%, test acc = 74.24%
# Epoch 263: train loss = 0.5237, train acc = 90.23%, test acc = 74.83%
# Epoch 264: train loss = 0.3011, train acc = 89.68%, test acc = 74.68%
# Epoch 265: train loss = 0.4629, train acc = 89.67%, test acc = 74.07%
# Epoch 266: train loss = 0.4564, train acc = 89.81%, test acc = 74.70%
# Epoch 267: train loss = 0.3855, train acc = 89.46%, test acc = 74.76%
# Epoch 268: train loss = 0.4068, train acc = 89.63%, test acc = 74.51%
# Epoch 269: train loss = 0.3526, train acc = 90.11%, test acc = 74.63%
# Epoch 270: train loss = 0.5281, train acc = 88.91%, test acc = 73.40%
# Epoch 271: train loss = 0.4196, train acc = 87.93%, test acc = 74.44%
# Epoch 272: train loss = 0.3805, train acc = 89.16%, test acc = 73.79%
# Epoch 273: train loss = 0.4148, train acc = 89.66%, test acc = 74.61%
# Epoch 274: train loss = 0.3862, train acc = 89.89%, test acc = 74.50%
# Epoch 275: train loss = 0.3811, train acc = 90.13%, test acc = 74.53%
# Epoch 276: train loss = 0.2976, train acc = 89.97%, test acc = 74.78%
# Epoch 277: train loss = 0.3406, train acc = 89.96%, test acc = 74.66%
# Epoch 278: train loss = 0.4668, train acc = 89.62%, test acc = 74.14%
# Epoch 279: train loss = 0.3209, train acc = 90.07%, test acc = 74.01%
# Epoch 280: train loss = 0.3557, train acc = 90.11%, test acc = 73.81%
# Epoch 281: train loss = 0.4210, train acc = 90.21%, test acc = 74.74%
# Epoch 282: train loss = 0.3837, train acc = 89.97%, test acc = 74.68%
# Epoch 283: train loss = 0.4575, train acc = 89.87%, test acc = 73.26%
# Epoch 284: train loss = 0.3774, train acc = 89.59%, test acc = 74.48%
# Epoch 285: train loss = 0.4552, train acc = 89.71%, test acc = 74.22%
# Epoch 286: train loss = 0.4108, train acc = 89.56%, test acc = 73.66%
# Epoch 287: train loss = 0.3688, train acc = 89.38%, test acc = 73.62%
# Epoch 288: train loss = 0.4011, train acc = 89.59%, test acc = 74.20%
# Epoch 289: train loss = 0.3933, train acc = 89.93%, test acc = 74.40%
# Epoch 290: train loss = 0.4007, train acc = 90.11%, test acc = 73.84%
# Epoch 291: train loss = 0.3740, train acc = 90.14%, test acc = 73.96%
# Epoch 292: train loss = 0.3591, train acc = 90.10%, test acc = 74.05%
# Epoch 293: train loss = 0.3327, train acc = 90.72%, test acc = 74.51%
# Epoch 294: train loss = 0.3355, train acc = 90.32%, test acc = 74.79%
# Epoch 295: train loss = 0.3953, train acc = 90.24%, test acc = 74.40%
# Epoch 296: train loss = 0.4273, train acc = 89.78%, test acc = 73.73%
# Epoch 297: train loss = 0.3101, train acc = 89.76%, test acc = 74.51%
# Epoch 298: train loss = 0.3966, train acc = 90.22%, test acc = 74.38%
# Epoch 299: train loss = 0.3256, train acc = 90.31%, test acc = 73.86%
# Epoch 300: train loss = 0.4766, train acc = 89.88%, test acc = 73.19%
# Epoch 301: train loss = 0.4161, train acc = 89.67%, test acc = 74.33%
# Epoch 302: train loss = 0.4040, train acc = 90.22%, test acc = 74.05%
# Epoch 303: train loss = 0.4139, train acc = 90.17%, test acc = 74.24%
# Epoch 304: train loss = 0.3313, train acc = 90.41%, test acc = 74.37%
# Epoch 305: train loss = 0.4182, train acc = 90.25%, test acc = 74.78%
# Epoch 306: train loss = 0.3974, train acc = 90.05%, test acc = 74.57%
# Epoch 307: train loss = 0.3368, train acc = 90.00%, test acc = 74.85%
# Epoch 308: train loss = 0.3237, train acc = 90.42%, test acc = 74.40%
# Epoch 309: train loss = 0.3064, train acc = 89.75%, test acc = 74.20%
# Epoch 310: train loss = 0.4118, train acc = 90.26%, test acc = 73.92%
# Epoch 311: train loss = 0.4206, train acc = 89.66%, test acc = 74.42%
# Epoch 312: train loss = 0.3813, train acc = 90.19%, test acc = 74.66%
# Epoch 313: train loss = 0.3751, train acc = 90.06%, test acc = 74.31%
# Epoch 314: train loss = 0.3665, train acc = 90.39%, test acc = 74.70%
# Epoch 315: train loss = 0.4439, train acc = 90.56%, test acc = 74.14%
# Epoch 316: train loss = 0.3733, train acc = 90.54%, test acc = 73.92%
# Epoch 317: train loss = 0.3645, train acc = 90.26%, test acc = 73.90%
# Epoch 318: train loss = 0.3814, train acc = 90.43%, test acc = 74.93%
# Epoch 319: train loss = 0.4115, train acc = 89.23%, test acc = 73.75%
# Epoch 320: train loss = 0.3989, train acc = 89.85%, test acc = 74.78%
# Epoch 321: train loss = 0.3805, train acc = 90.54%, test acc = 74.40%
# Epoch 322: train loss = 0.3845, train acc = 90.83%, test acc = 74.29%
# Epoch 323: train loss = 0.3576, train acc = 90.32%, test acc = 74.37%
# Epoch 324: train loss = 0.3584, train acc = 90.35%, test acc = 73.51%
# Epoch 325: train loss = 0.3521, train acc = 90.00%, test acc = 74.16%
# Epoch 326: train loss = 0.3578, train acc = 90.33%, test acc = 74.37%
# Epoch 327: train loss = 0.4975, train acc = 90.38%, test acc = 74.12%
# Epoch 328: train loss = 0.4420, train acc = 90.44%, test acc = 74.70%
# Epoch 329: train loss = 0.3293, train acc = 90.65%, test acc = 74.76%
# Epoch 330: train loss = 0.3179, train acc = 90.78%, test acc = 74.63%
# Epoch 331: train loss = 0.3479, train acc = 90.44%, test acc = 74.70%
# Epoch 332: train loss = 0.4082, train acc = 90.25%, test acc = 74.12%
# Epoch 333: train loss = 0.3410, train acc = 90.59%, test acc = 73.69%
# Epoch 334: train loss = 0.2736, train acc = 90.33%, test acc = 74.79%
# Epoch 335: train loss = 0.3954, train acc = 90.54%, test acc = 74.96%
# Epoch 336: train loss = 0.3993, train acc = 90.87%, test acc = 74.74%
# Epoch 337: train loss = 0.2867, train acc = 90.69%, test acc = 74.25%
# Epoch 338: train loss = 0.3993, train acc = 90.73%, test acc = 74.87%
# Epoch 339: train loss = 0.4026, train acc = 90.44%, test acc = 74.96%
# Epoch 340: train loss = 0.3363, train acc = 90.64%, test acc = 74.33%
# Epoch 341: train loss = 0.3320, train acc = 90.71%, test acc = 74.25%
# Epoch 342: train loss = 0.3474, train acc = 90.94%, test acc = 74.20%
# Epoch 343: train loss = 0.3794, train acc = 90.50%, test acc = 74.57%
# Epoch 344: train loss = 0.3245, train acc = 89.83%, test acc = 74.24%
# Epoch 345: train loss = 0.3673, train acc = 90.49%, test acc = 73.96%
# Epoch 346: train loss = 0.3548, train acc = 90.54%, test acc = 74.46%
# Epoch 347: train loss = 0.4608, train acc = 90.05%, test acc = 74.40%
# Epoch 348: train loss = 0.3565, train acc = 90.46%, test acc = 74.35%
# Epoch 349: train loss = 0.5022, train acc = 88.24%, test acc = 73.77%
# Epoch 350: train loss = 0.3939, train acc = 89.35%, test acc = 75.63% !!
# Epoch 351: train loss = 0.4431, train acc = 90.24%, test acc = 74.68%
# Epoch 352: train loss = 0.3917, train acc = 90.33%, test acc = 74.44%
# Epoch 353: train loss = 0.3503, train acc = 90.96%, test acc = 74.35%
# Epoch 354: train loss = 0.4646, train acc = 90.55%, test acc = 74.25%
# Epoch 355: train loss = 0.3526, train acc = 90.06%, test acc = 74.42%
# Epoch 356: train loss = 0.3886, train acc = 90.35%, test acc = 74.70%
# Epoch 357: train loss = 0.3606, train acc = 90.51%, test acc = 74.63%
# Epoch 358: train loss = 0.3276, train acc = 90.81%, test acc = 74.46%
# Epoch 359: train loss = 0.4507, train acc = 90.93%, test acc = 74.33%
# Epoch 360: train loss = 0.3160, train acc = 90.23%, test acc = 74.37%
# Epoch 361: train loss = 0.3968, train acc = 90.36%, test acc = 73.54%
# Epoch 362: train loss = 0.3636, train acc = 89.59%, test acc = 73.92%
# Epoch 363: train loss = 0.3936, train acc = 90.24%, test acc = 74.72%
# Epoch 364: train loss = 0.3932, train acc = 90.75%, test acc = 74.66%
# Epoch 365: train loss = 0.3073, train acc = 91.03%, test acc = 74.37%
# Epoch 366: train loss = 0.3966, train acc = 91.04%, test acc = 74.16%
# Epoch 367: train loss = 0.3945, train acc = 89.95%, test acc = 75.24%
# Epoch 368: train loss = 0.3743, train acc = 90.72%, test acc = 74.38%
# Epoch 369: train loss = 0.3394, train acc = 90.32%, test acc = 75.13%
# Epoch 370: train loss = 0.3670, train acc = 90.92%, test acc = 74.72%
# Epoch 371: train loss = 0.3470, train acc = 91.29%, test acc = 74.65%
# Epoch 372: train loss = 0.3471, train acc = 90.73%, test acc = 74.76%
# Epoch 373: train loss = 0.3023, train acc = 91.06%, test acc = 74.46%
# Epoch 374: train loss = 0.3331, train acc = 91.21%, test acc = 74.61%
# Epoch 375: train loss = 0.3347, train acc = 91.11%, test acc = 74.66%
# Epoch 376: train loss = 0.3843, train acc = 91.25%, test acc = 75.30%
# Epoch 377: train loss = 0.4008, train acc = 91.45%, test acc = 74.61%
# Epoch 378: train loss = 0.3472, train acc = 91.41%, test acc = 75.07%
# Epoch 379: train loss = 0.3246, train acc = 90.93%, test acc = 75.00%
# Epoch 380: train loss = 0.3465, train acc = 91.10%, test acc = 74.53%
# Epoch 381: train loss = 0.3605, train acc = 90.46%, test acc = 74.93%
# Epoch 382: train loss = 0.3263, train acc = 89.91%, test acc = 74.40%
# Epoch 383: train loss = 0.4024, train acc = 90.87%, test acc = 74.31%
# Epoch 384: train loss = 0.3948, train acc = 91.13%, test acc = 74.33%
# Epoch 385: train loss = 0.3614, train acc = 90.38%, test acc = 73.75%
# Epoch 386: train loss = 0.4114, train acc = 89.65%, test acc = 73.79%
# Epoch 387: train loss = 0.3798, train acc = 90.21%, test acc = 74.91%
# Epoch 388: train loss = 0.3216, train acc = 91.32%, test acc = 74.87%
# Epoch 389: train loss = 0.3642, train acc = 90.69%, test acc = 73.90%
# Epoch 390: train loss = 0.3677, train acc = 90.51%, test acc = 74.94%
# Epoch 391: train loss = 0.3227, train acc = 90.90%, test acc = 74.74%
# Epoch 392: train loss = 0.3327, train acc = 90.70%, test acc = 73.97%
# Epoch 393: train loss = 0.3628, train acc = 90.73%, test acc = 74.59%
# Epoch 394: train loss = 0.3980, train acc = 90.98%, test acc = 75.35%
# Epoch 395: train loss = 0.2914, train acc = 91.06%, test acc = 74.61%
# Epoch 396: train loss = 0.3370, train acc = 91.25%, test acc = 74.83%
# Epoch 397: train loss = 0.3840, train acc = 90.64%, test acc = 74.50%
# Epoch 398: train loss = 0.3823, train acc = 90.35%, test acc = 74.33%
# Epoch 399: train loss = 0.3116, train acc = 91.15%, test acc = 74.18%
# Epoch 400: train loss = 0.3001, train acc = 90.88%, test acc = 74.59%
# Epoch 401: train loss = 0.4105, train acc = 91.09%, test acc = 74.05%
# Epoch 402: train loss = 0.3975, train acc = 90.65%, test acc = 74.53%
# Epoch 403: train loss = 0.3784, train acc = 90.30%, test acc = 73.86%
# Epoch 404: train loss = 0.4591, train acc = 90.76%, test acc = 74.85%
# Epoch 405: train loss = 0.3042, train acc = 90.98%, test acc = 75.17%
# Epoch 406: train loss = 0.3453, train acc = 90.51%, test acc = 74.81%
# Epoch 407: train loss = 0.3510, train acc = 90.77%, test acc = 74.55%
# Epoch 408: train loss = 0.3525, train acc = 91.17%, test acc = 74.53%
# Epoch 409: train loss = 0.3602, train acc = 91.34%, test acc = 74.68%
# Epoch 410: train loss = 0.3910, train acc = 91.31%, test acc = 74.37%
# Epoch 411: train loss = 0.3385, train acc = 90.29%, test acc = 73.88%
# Epoch 412: train loss = 0.4008, train acc = 90.54%, test acc = 74.59%
# Epoch 413: train loss = 0.3135, train acc = 91.22%, test acc = 74.09%
# Epoch 414: train loss = 0.3733, train acc = 91.20%, test acc = 74.74%
# Epoch 415: train loss = 0.3315, train acc = 91.10%, test acc = 74.85%
# Epoch 416: train loss = 0.3582, train acc = 91.50%, test acc = 74.93%
# Epoch 417: train loss = 0.4263, train acc = 91.13%, test acc = 74.65%
# Epoch 418: train loss = 0.3056, train acc = 91.00%, test acc = 74.78%
# Epoch 419: train loss = 0.3576, train acc = 91.25%, test acc = 75.19%
# Epoch 420: train loss = 0.3707, train acc = 91.17%, test acc = 74.24%
# Epoch 421: train loss = 0.3417, train acc = 91.61%, test acc = 73.92%
# Epoch 422: train loss = 0.3713, train acc = 91.14%, test acc = 74.48%
# Epoch 423: train loss = 0.3933, train acc = 90.69%, test acc = 74.59%
# Epoch 424: train loss = 0.3203, train acc = 90.14%, test acc = 75.02%
# Epoch 425: train loss = 0.2871, train acc = 90.29%, test acc = 74.40%
# Epoch 426: train loss = 0.3971, train acc = 91.32%, test acc = 74.29%
# Epoch 427: train loss = 0.2971, train acc = 91.03%, test acc = 74.89%
# Epoch 428: train loss = 0.3160, train acc = 91.13%, test acc = 73.58%
# Epoch 429: train loss = 0.3391, train acc = 91.18%, test acc = 75.26%
# Epoch 430: train loss = 0.3345, train acc = 91.01%, test acc = 74.37%
# Epoch 431: train loss = 0.3705, train acc = 91.20%, test acc = 75.30%
# Epoch 432: train loss = 0.4070, train acc = 90.79%, test acc = 74.83%
# Epoch 433: train loss = 0.3546, train acc = 90.73%, test acc = 74.83%
# Epoch 434: train loss = 0.4136, train acc = 90.96%, test acc = 74.37%
# Epoch 435: train loss = 0.3085, train acc = 91.14%, test acc = 75.65% !!
# Epoch 436: train loss = 0.3622, train acc = 90.91%, test acc = 74.66%
# Epoch 437: train loss = 0.3258, train acc = 91.48%, test acc = 74.78%
# Epoch 438: train loss = 0.4266, train acc = 90.94%, test acc = 74.76%
# Epoch 439: train loss = 0.3011, train acc = 90.39%, test acc = 74.65%
# Epoch 440: train loss = 0.3978, train acc = 91.03%, test acc = 74.07%
# Epoch 441: train loss = 0.4036, train acc = 91.05%, test acc = 75.06%
# Epoch 442: train loss = 0.3296, train acc = 91.06%, test acc = 74.93%
# Epoch 443: train loss = 0.3453, train acc = 91.27%, test acc = 74.55%
# Epoch 444: train loss = 0.3335, train acc = 91.78%, test acc = 75.17%
# Epoch 445: train loss = 0.3408, train acc = 91.58%, test acc = 74.51%
# Epoch 446: train loss = 0.3299, train acc = 90.97%, test acc = 74.70%
# Epoch 447: train loss = 0.3930, train acc = 90.79%, test acc = 74.05%
# Epoch 448: train loss = 0.4275, train acc = 90.69%, test acc = 75.06%
# Epoch 449: train loss = 0.3210, train acc = 90.92%, test acc = 73.81%
# Epoch 450: train loss = 0.3161, train acc = 91.30%, test acc = 75.26%
# Epoch 451: train loss = 0.3036, train acc = 91.34%, test acc = 75.22%
# Epoch 452: train loss = 0.2863, train acc = 91.65%, test acc = 74.61%
# Epoch 453: train loss = 0.3949, train acc = 91.47%, test acc = 75.60%
# Epoch 454: train loss = 0.3105, train acc = 91.29%, test acc = 75.13%
# Epoch 455: train loss = 0.2815, train acc = 91.39%, test acc = 75.00%
# Epoch 456: train loss = 0.3559, train acc = 91.20%, test acc = 74.18%
# Epoch 457: train loss = 0.3024, train acc = 90.56%, test acc = 74.65%
# Epoch 458: train loss = 0.3690, train acc = 91.05%, test acc = 74.10%
# Epoch 459: train loss = 0.3957, train acc = 90.87%, test acc = 74.31%
# Epoch 460: train loss = 0.3633, train acc = 91.50%, test acc = 75.32%
# Epoch 461: train loss = 0.3138, train acc = 91.41%, test acc = 74.09%
# Epoch 462: train loss = 0.3579, train acc = 91.26%, test acc = 74.96%
# Epoch 463: train loss = 0.4003, train acc = 90.75%, test acc = 74.01%
# Epoch 464: train loss = 0.3714, train acc = 90.12%, test acc = 74.46%
# Epoch 465: train loss = 0.3418, train acc = 90.57%, test acc = 75.06%
# Epoch 466: train loss = 0.3642, train acc = 91.31%, test acc = 74.89%
# Epoch 467: train loss = 0.3759, train acc = 91.08%, test acc = 74.53%
# Epoch 468: train loss = 0.3514, train acc = 91.04%, test acc = 74.38%
# Epoch 469: train loss = 0.3137, train acc = 91.47%, test acc = 74.38%
# Epoch 470: train loss = 0.2722, train acc = 92.03%, test acc = 75.22%
# Epoch 471: train loss = 0.4615, train acc = 90.41%, test acc = 74.76%
# Epoch 472: train loss = 0.3423, train acc = 90.42%, test acc = 74.83%
# Epoch 473: train loss = 0.3300, train acc = 91.17%, test acc = 74.87%
# Epoch 474: train loss = 0.3363, train acc = 91.34%, test acc = 75.65%
# Epoch 475: train loss = 0.3211, train acc = 91.31%, test acc = 74.70%
# Epoch 476: train loss = 0.3644, train acc = 91.50%, test acc = 74.46%
# Epoch 477: train loss = 0.4001, train acc = 91.66%, test acc = 75.34%
# Epoch 478: train loss = 0.3674, train acc = 91.58%, test acc = 75.24%
# Epoch 479: train loss = 0.3264, train acc = 91.71%, test acc = 75.09%
# Epoch 480: train loss = 0.3569, train acc = 91.33%, test acc = 74.63%
# Epoch 481: train loss = 0.3402, train acc = 91.28%, test acc = 74.33%
# Epoch 482: train loss = 0.3456, train acc = 91.68%, test acc = 75.00%
# Epoch 483: train loss = 0.3216, train acc = 91.62%, test acc = 74.05%
# Epoch 484: train loss = 0.3667, train acc = 91.67%, test acc = 75.43%
# Epoch 485: train loss = 0.2878, train acc = 91.39%, test acc = 74.76%
# Epoch 486: train loss = 0.2956, train acc = 91.68%, test acc = 74.91%
# Epoch 487: train loss = 0.3693, train acc = 91.58%, test acc = 75.00%
# Epoch 488: train loss = 0.2848, train acc = 91.58%, test acc = 75.15%
# Epoch 489: train loss = 0.2658, train acc = 91.73%, test acc = 74.98%
# Epoch 490: train loss = 0.2866, train acc = 91.25%, test acc = 74.59%
# Epoch 491: train loss = 0.3178, train acc = 91.48%, test acc = 74.66%
# Epoch 492: train loss = 0.3214, train acc = 91.51%, test acc = 74.59%
# Epoch 493: train loss = 0.2572, train acc = 91.50%, test acc = 74.79%
# Epoch 494: train loss = 0.3158, train acc = 91.66%, test acc = 75.22%
# Epoch 495: train loss = 0.4301, train acc = 91.51%, test acc = 75.21%
# Epoch 496: train loss = 0.3378, train acc = 91.49%, test acc = 74.16%
# Epoch 497: train loss = 0.2833, train acc = 91.14%, test acc = 74.85%
# Epoch 498: train loss = 0.3673, train acc = 91.75%, test acc = 75.32%
# Epoch 499: train loss = 0.2978, train acc = 91.70%, test acc = 73.97%
# Epoch 500: train loss = 0.3330, train acc = 91.64%, test acc = 75.02%

# %%
# final results after testing approx. 30 different variations of dropout, learning rate, etc
# best learning rate = 0.001, batch size of 32/64, dropout rate around 0.2-0.5
# 200 epochs gives best results as test acc plateaus after that, prevents overfitting
# train/test split between 20-30% gives good results

# %%
# investigate TOP 5 ERROR of the model.
# compare with top 1 error (accuracy)

model.load_state_dict(best_model)
model.eval()

# get predictions for ALL testing data
k = 5
test_pred = model(x_test)
test_pred_top_k = torch.topk(test_pred, k=k, dim=1)[1]

total = 0
in_top_k = 0
for index, value in enumerate(y_test):
    if value in test_pred_top_k[index]: in_top_k += 1

    total += 1

top_k_accuracy = in_top_k * 100 / total

print(f"Top {k} Accuracy: {top_k_accuracy:.03f}%")
# Out:
# Top 5 Accuracy: 90.000%

# %%
folder_df["file"].value_counts()
# Out:
# file
# XC416747.mp3    275
# XC350953.ogg    198
# XC136060.ogg    191
# XC138069.ogg    170
# XC352051.ogg    166
#                ...
# XC348948.ogg      1
# XC425121.ogg      1
# XC193421.mp3      1
# XC321501.ogg      1
# XC736964.ogg      1
# Name: count, Length: 2055, dtype: int64

# %%
accuracy_df = pd.DataFrame(data=[y_test.cpu().numpy(), test_pred_top_k.cpu().numpy()], index=["actual", "pred"]).transpose()
accuracy_df["in_top_5"] = [1 if accuracy_df.iloc[i, 0] in accuracy_df.iloc[i, 1] else 0 for i in range(len(accuracy_df.index))]
folder_top_5 = accuracy_df.groupby(by="actual").aggregate(func=np.sum)["in_top_5"].values
folder_counts = accuracy_df.groupby(by="actual").aggregate(func=np.size)["in_top_5"].values
accuracy_df = pd.DataFrame(data=[folder_top_5, folder_counts], index=["in_top_5", "count"]).transpose()
accuracy_df["top_5_accuracy"] = round(accuracy_df["in_top_5"] * 100 / accuracy_df["count"], 2)
accuracy_df.sort_values(by="top_5_accuracy")
# Out:
#     in_top_5  count  top_5_accuracy
# 27        84    115           73.04
# 18        76    100           76.00
# 22        83    108           76.85
# 42        85    109           77.98
# 37        90    114           78.95
# 48        85    107           79.44
# 21        84    105           80.00
# 9         91    112           81.25
# 4         93    112           83.04
# 47        76     90           84.44
# 23        93    109           85.32
# 38        88    103           85.44
# 3         94    109           86.24
# 6         97    112           86.61
# 15        93    107           86.92
# 14       108    124           87.10
# 39        89    102           87.25
# 32        98    111           88.29
# 33       107    121           88.43
# 31        82     92           89.13
# 44        99    110           90.00
# 26       101    112           90.18
# 19        85     94           90.43
# 17       104    115           90.43
# 45        93    102           91.18
# 43       111    121           91.74
# 40        94    102           92.16
# 10       106    115           92.17
# 7        111    120           92.50
# 5         91     98           92.86
# 25        95    102           93.14
# 49       100    107           93.46
# 29        97    103           94.17
# 36        99    105           94.29
# 41        99    104           95.19
# 28        99    104           95.19
# 30       115    120           95.83
# 12       104    108           96.30
# 20       107    111           96.40
# 8        117    121           96.69
# 16        94     97           96.91
# 1         96     99           96.97
# 24        96     99           96.97
# 34        97    100           97.00
# 46        97    100           97.00
# 13       109    112           97.32
# 2        112    115           97.39
# 0         97     99           97.98
# 11       100    100          100.00
# 35       103    103          100.00

# %%
# takes in a whole file as input, feeds into the model, performs sequential aggregation
# gives a single output based on aggregation strategy
def test_file(folder, file_path):
    global sample_rate, split_length, model
    samples = []
    
    # load file data and resample to sample_rate if necessary
    file_data, file_sample_rate_hz = torchaudio.load(uri=file_path, channels_first=True)
    if file_sample_rate_hz != sample_rate:
        file_data = torchaudio.functional.resample(file_data, orig_freq=file_sample_rate_hz, new_freq=sample_rate)

    # convert all audio into mono (1 channel) if audio is stereo (2 channels)
    if file_data.shape[0] == 2: file_data = file_data.mean(dim=0)
    else: file_data = file_data.flatten()

    # get total number of X second splits
    total_splits = floor(len(file_data) / int(sample_rate * split_interval_secs))
    
    # convert file data into mel-spectrogram fourier transform for feeding into CNN
    n_fft = 1024

    mel_spec_transform = torchaudio.transforms.MelSpectrogram(sample_rate = sample_rate, power=2, n_fft=n_fft)
    amp_to_db_transform = torchaudio.transforms.AmplitudeToDB(stype="amplitude", top_db=80)
    mel_spec_data_db = amp_to_db_transform(mel_spec_transform(file_data))
    
    # if file is at least X seconds.
    if total_splits >= 1:
        split_length = min(mel_spec_data_db.shape[1] // total_splits, split_length)
        mel_spec_splits = np.arange(0, mel_spec_data_db.shape[1], split_length)
        for i in range(len(mel_spec_splits) - 1):
            start = mel_spec_splits[i]
            end = mel_spec_splits[i + 1]

            mel_spec_split = mel_spec_data_db[:, start:end]

            # add testing sample to end
            samples.append(mel_spec_split.reshape(1, 128, -1).numpy())
    else:
        return None

    samples = torch.Tensor(np.array(samples)).to(device)

    preds = model(samples)

    # Ax[classes] sized array, A = number of splits in file

    # sequential aggregation via summation
    #seq_aggregation_result = torch.sum(preds, dim=0)
    # sequential aggregation via normalisation + summation (appears to be the best solution right now, but barely by much)
    seq_aggregation_result = torch.sum(nn.functional.normalize(preds, dim=1), dim=0)
    # sequential aggregation via normalisation + sigmoid + summation
    #seq_aggregation_result = torch.sum(torch.sigmoid(nn.functional.normalize(preds, dim=1)), dim=0)
    # sequential aggregation via normalisation + summation
    #seq_aggregation_result = torch.sum(nn.functional.sigmoid(preds), dim=0)


    prediction_order = [folder_key[i] for i in torch.topk(seq_aggregation_result, k=len(seq_aggregation_result)).indices.cpu().numpy()]
    location = prediction_order.index(folder) + 1 # because of zero index, adjust to make it 1-indexed

    return location, prediction_order

# %%
random_folder = "../../datasets/birdsongs-combined/train_audio/" + random.choice([i for i in folder_key.values()]) + "/"
random_file = random_folder + random.choice(os.listdir(random_folder))

print(random_file)

test_file(random_folder.split("/")[-2], random_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 random_folder = "../../datasets/birdsongs-combined/train_audio/" + random.choice([i for i in folder_key.values()]) + "/"
# ----> 2 random_file = random_folder + random.choice(os.listdir(random_folder))
#       4 print(random_file)
#       6 test_file(random_folder.split("/")[-2], random_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../datasets/birdsongs-combined/train_audio/yehcar1/'

# %%
# do above but for EVERY SINGLE FILE in the classes used

base_path = "../../datasets/birdsongs-combined/train_audio/"

valid_files = set([l.replace("\n", "") for l in open(f"rating_thresholds_at_least_10_classes/min_rating_{int(min_rating * 2)}.txt").readlines()])
sequential_aggregation_results = {}

for folder in (progress_bar := tqdm(folder_key.values())):

    folder_path = base_path + folder + "/"

    folder_length = len(os.listdir(folder_path))
    file_counter = 0
    for file in os.listdir(folder_path):
        file_counter += 1
        progress_bar.set_description(f"{folder} - {file_counter}/{folder_length}")
        
        file_path = folder_path + file

        if folder + "/" + file in valid_files:
            result = test_file(folder, file_path)
            if result:
                sequential_aggregation_results[folder] = sequential_aggregation_results.get(folder, []) + [result[0]]

# %%
rows = []

for folder in sequential_aggregation_results.keys():
    row = {}

    results = sequential_aggregation_results[folder]

    row["folder"] = folder
    row["total_files"] = len(results)
    row["in_top_1_percentage"] = round(sum([1 if result == 1 else 0 for result in results]) * 100 / len(results), 2)
    row["in_top_5_percentage"] = round(sum([1 if result <= 5 else 0 for result in results]) * 100 / len(results), 2)

    rows.append(row)

sequential_aggregation_df = pd.DataFrame(rows)

sequential_aggregation_df["top_1_product"] = sequential_aggregation_df["total_files"] * sequential_aggregation_df["in_top_1_percentage"]
sequential_aggregation_df["top_5_product"] = sequential_aggregation_df["total_files"] * sequential_aggregation_df["in_top_5_percentage"]

print(sum(sequential_aggregation_df["top_1_product"]) / sum(sequential_aggregation_df["total_files"]))
print(sum(sequential_aggregation_df["top_5_product"]) / sum(sequential_aggregation_df["total_files"]))

sequential_aggregation_df.sort_values(by="in_top_5_percentage", ascending=False)
