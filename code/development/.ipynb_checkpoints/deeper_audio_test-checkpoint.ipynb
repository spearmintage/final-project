# %% [markdown]
# goal:
#
# - use librosa on 1000 audio files and/or 50 class folders minimum
# - store information in a dataframe (excluding actual file data for now)
#   - folder name, file name, sampling rate, data length, file length, file size(?)

# %%
import pandas as pd
import numpy as np
import random
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchaudio
import copy
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

from tqdm import tqdm
from IPython.display import Audio

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from imblearn.over_sampling import RandomOverSampler

from math import floor

import sys

# %%
# experimental parameters for model training, for simple configuration in a single cell.
# very useful for reporting spreadsheet

folder_key = {}

split_interval_secs = 2
split_length = 10000000000000 # absurd number for future use
sample_rate = 32000

variance_threshold = 0.2
mean_threshold = 5

total_folders = 200
min_rating = 5.0
max_files_per_folder = 20

sampling_technique = "median"

test_size = 0.2

epochs = 500
batch_size = 1024
dropout_rate = 0.5
learning_rate = 0.001
momentum = 0
experimental = False
experimental_counter_limit = 10
save_best_to_file = False

# %%
def reset_seed():
    torch.manual_seed(1368)
    random.seed(1368)
    np.random.seed(1368)

reset_seed()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i in range(torch.cuda.device_count()):
   print(torch.cuda.get_device_properties(i).total_memory)

print(device)
print(torch.cuda.get_device_name())
# Out:
# 85100068864
# cuda
# NVIDIA A100 80GB PCIe

# %%
# base_dir: directory of all the audio file folders
# split_interval_secs: the length of each sound clip when split up in a file.
#   - final dataframe will not contain any sound clips over/under this length
# sample_rate: sample rate of sound clips in hz
# total_folders: total folders to iterate through the files, given range of files per folder
# min_files_per_folder: minimum files to exist in the folder
# max_files_per_folder: maximum files to use inside the folder
def get_random_folders_filtered(base_dir: str, split_interval_secs: float, sample_rate: int = 32000, total_folders: int = 50, max_files_per_folder: int = -1, min_rating: float = 4.0):
    global split_length, folder_key

    # get the list of valid folders and files to analyse
    folder_key = {}

    folders = []
    valid_folders = set()
    valid_files = set([l.replace("\n", "") for l in open(f"rating_thresholds_at_least_10_classes/min_rating_{int(min_rating * 2)}.txt").readlines()])
    for f in valid_files: valid_folders.add(f.split("/")[0])
    for folder in [line.replace("\n", "") for line in open("folder_order.txt").readlines()]:
        if folder in valid_folders:
            folders.append(folder)

    folder_count = 0

    # if there are less folders than those specified, view all folders instead of given amount
    total_folders = min(len(folders), total_folders)

    rows = []
    
    for folder in folders:
        
        folder_path = base_dir + folder + "/"
        valid_folder_files = []
        # only iterate through the valid audio files
        for file in os.listdir(folder_path):
            if folder + "/" + file in valid_files:
                valid_folder_files.append(folder_path + file)
        random.shuffle(valid_folder_files)

        if max_files_per_folder > 0:
            valid_folder_files = valid_folder_files[:min(max_files_per_folder, len(valid_folder_files))]

        # iterate through each file in the folder
        for file_path in (progress_bar := tqdm(valid_folder_files)):
            # load file data and resample to sample_rate if necessary
            file_data, file_sample_rate_hz = torchaudio.load(uri=file_path, channels_first=True)
            if file_sample_rate_hz != sample_rate:
                file_data = torchaudio.functional.resample(file_data, orig_freq=file_sample_rate_hz, new_freq=sample_rate)

            # convert all audio into mono (1 channel) if audio is stereo (2 channels)
            if file_data.shape[0] == 2:
                file_data = file_data.mean(dim=0)
            else:
                file_data = file_data.flatten()

            # get total number of X second splits
            total_splits = floor(len(file_data) / int(sample_rate * split_interval_secs))
            
            # convert file data into mel-spectrogram fourier transform for feeding into CNN
            n_fft = 1024

            mel_spec_transform = torchaudio.transforms.MelSpectrogram(sample_rate = sample_rate, power=2, n_fft=n_fft)
            amp_to_db_transform = torchaudio.transforms.AmplitudeToDB(stype="amplitude", top_db=80)
            mel_spec_data_db = amp_to_db_transform(mel_spec_transform(file_data)).numpy()
            
            # if file is at least X seconds.
            if total_splits >= 1:
                split_length = min(mel_spec_data_db.shape[1] // total_splits, split_length)
                mel_spec_splits = np.arange(0, mel_spec_data_db.shape[1], split_length)
                for i in range(len(mel_spec_splits) - 1):
                    start = mel_spec_splits[i]
                    end = mel_spec_splits[i + 1]

                    mel_spec_split = mel_spec_data_db[:, start:end]

                    row = {}
                    row["folder"] = folder
                    row["file"] = file_path.split("/")[-1]
                    row["mel_spec"] = mel_spec_split
                    row["mel_spec_shape"] = mel_spec_split.shape

                    # determine and filter for "silence":
                    var = np.var(mel_spec_split)
                    # mean = torch.mean(mel_spec_split)

                    if not (var <= variance_threshold):
                        rows.append(row)

                folder_key[folder_count] = folder
            
            progress_bar.set_description(f"Folder {folder_count + 1}/{total_folders} - {folder}")
        
        # end loop if total_folders has been reached
        folder_count += 1
        if folder_count >= total_folders: break

    # trim the ends of some mel spectrograms because of stupid floating point nonsense
    for i, row in enumerate(rows):
        if row["mel_spec_shape"][1] != split_length:
            row["mel_spec"] = row["mel_spec"][:, :split_length]
            row["mel_spec_shape"] = row["mel_spec"].shape

    return pd.DataFrame(rows)

# %%
base_dir = "/mnt/lustre/peprmint/train_audio/"
#base_dir = "../../datasets/birdsongs-combined/train_audio/"

reset_seed()

folder_df = get_random_folders_filtered(
    base_dir, 
    split_interval_secs=split_interval_secs, 
    sample_rate=sample_rate,
    total_folders=total_folders,
    min_rating=min_rating,
    max_files_per_folder=max_files_per_folder
)
# Out:
# Folder 1/200 - dowwoo: 100%|██████████| 20/20 [00:01<00:00, 10.94it/s]
# Folder 2/200 - rerswa1: 100%|██████████| 20/20 [00:01<00:00, 18.96it/s]
# Folder 3/200 - cobtan1: 100%|██████████| 20/20 [00:01<00:00, 14.37it/s]
# Folder 4/200 - barswa: 100%|██████████| 20/20 [00:01<00:00, 15.63it/s]
# Folder 5/200 - indbun: 100%|██████████| 20/20 [00:02<00:00,  8.39it/s]
# Folder 6/200 - comloo: 100%|██████████| 10/10 [00:00<00:00, 10.33it/s]
# Folder 7/200 - mitpar: 100%|██████████| 14/14 [00:01<00:00,  8.76it/s]
# Folder 8/200 - blhpar1: 100%|██████████| 20/20 [00:01<00:00, 19.18it/s]
# Folder 9/200 - amepip: 100%|██████████| 20/20 [00:00<00:00, 22.45it/s]
# Folder 10/200 - brnjay: 100%|██████████| 20/20 [00:01<00:00, 14.22it/s]
# Folder 11/200 - sheowl: 100%|██████████| 20/20 [00:03<00:00,  6.65it/s]
# Folder 12/200 - peflov: 100%|██████████| 13/13 [00:00<00:00, 13.13it/s]
# Folder 13/200 - zebdov: 100%|██████████| 12/12 [00:00<00:00, 14.23it/s]
# Folder 14/200 - yehcar1: 100%|██████████| 20/20 [00:00<00:00, 26.43it/s]
# Folder 15/200 - cubthr: 100%|██████████| 20/20 [00:01<00:00, 10.90it/s]
# Folder 16/200 - amtspa:  50%|█████     | 8/16 [00:00<00:00,  8.18it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Folder 16
# Folder 176/200 - amered: 100%|██████████| 20/20 [00:01<00:00, 15.42it/s]
# Folder 177/200 - categr: 100%|██████████| 20/20 [00:00<00:00, 22.72it/s]
# Folder 178/200 - bushti: 100%|██████████| 20/20 [00:00<00:00, 23.73it/s]
# Folder 179/200 - rinkin1: 100%|██████████| 20/20 [00:00<00:00, 33.75it/s]
# Folder 180/200 - indpit1: 100%|██████████| 20/20 [00:00<00:00, 24.78it/s]
# Folder 181/200 - lesgre1: 100%|██████████| 20/20 [00:01<00:00, 19.94it/s]
# Folder 182/200 - yebcha: 100%|██████████| 20/20 [00:01<00:00, 11.35it/s]
# Folder 183/200 - yebela1: 100%|██████████| 20/20 [00:00<00:00, 24.38it/s]
# Folder 184/200 - aldfly: 100%|██████████| 10/10 [00:00<00:00, 12.27it/s]
# Folder 185/200 - ashwoo2: 100%|██████████| 11/11 [00:00<00:00, 30.17it/s]
# Folder 186/200 - orbeup1: 100%|██████████| 20/20 [00:00<00:00, 26.64it/s]
# Folder 187/200 - gnbcam2: 100%|██████████| 20/20 [00:00<00:00, 29.36it/s]
# Folder 188/200 - dunlin: 100%|██████████| 20/20 [00:00<00:00, 23.34it/s]
# Folder 189/200 - gohque1: 100%|██████████| 20/20 [00:00<00:00, 30.44it/s]
# Folder 190/200 - renpha: 100%|██████████| 18/18 [00:15<00:00,  1.13it/s]
# Folder 191/200 - cohmar1: 100%|██████████| 20/20 [00:00<00:00, 24.47it/s]
# Folder 192/200 - strcuc1: 100%|██████████| 20/20 [00:00<00:00, 21.05it/s]
# Folder 193/200 - sthant1: 100%|██████████| 20/20 [00:00<00:00, 24.41it/s]
# Folder 194/200 - grenig1: 100%|██████████| 18/18 [00:00<00:00, 37.74it/s]
# Folder 195/200 - houwre: 100%|██████████| 20/20 [00:01<00:00, 14.63it/s]
# Folder 196/200 - bkwsti: 100%|██████████| 20/20 [00:00<00:00, 28.56it/s]
# Folder 197/200 - bkctch1: 100%|██████████| 15/15 [00:00<00:00, 23.94it/s]
# Folder 198/200 - sltnig1: 100%|██████████| 17/17 [00:00<00:00, 26.73it/s]
# Folder 199/200 - burpar: 100%|██████████| 12/12 [00:00<00:00, 27.10it/s]
# Folder 200/200 - chispa: 100%|██████████| 20/20 [00:01<00:00, 11.79it/s]

# %%
folder_df.head()
# Out:
#    folder          file                                           mel_spec  \
# 0  dowwoo  XC193421.mp3  [[-2.843811, -2.843811, -2.843811, -2.843811, ...
# 1  dowwoo  XC567618.ogg  [[7.980774, 44.000854, 34.73201, 31.62218, 30....
# 2  dowwoo  XC567618.ogg  [[35.344337, 21.66115, 7.980774, 29.993248, 29...
# 3  dowwoo  XC567618.ogg  [[40.685463, 29.046001, 24.660858, 7.980774, 2...
# 4  dowwoo  XC567618.ogg  [[33.21062, 19.036201, 24.033766, 36.39653, 37...
#
#   mel_spec_shape
# 0     (128, 125)
# 1     (128, 125)
# 2     (128, 125)
# 3     (128, 125)
# 4     (128, 125)

# %%
folder_df["mel_spec_shape"].value_counts()
# Out:
# mel_spec_shape
# (128, 125)    75131
# Name: count, dtype: int64

# %%
folder_df["folder"].value_counts()
# Out:
# folder
# blrwar1    3562
# banswa     1457
# vesspa     1167
# thbwar1    1097
# woothr     1016
#            ...
# comfla1     121
# litegr      118
# brthum      110
# brubru1     101
# rehbar1      80
# Name: count, Length: 200, dtype: int64

# %%
print("sound clips BEFORE any sampling:", len(folder_df))
# Out:
# sound clips BEFORE any sampling: 75131

# %%
len(folder_df["folder"].unique())
# Out:
# 200

# %%
folder_df["folder"].value_counts().plot.bar(title="Value counts before over/under sampling.")
# Out:
# <Axes: title={'center': 'Value counts before over/under sampling.'}, xlabel='folder'>

# %%
# apply random undersampling OR oversampling

reset_seed()

if sampling_technique == "under":
    # random "naive" undersampling
    # delete random rows from all classes except minority class(es)
    min_folder_count = min(folder_df["folder"].value_counts())

    indices_to_keep = np.array([])

    for f in folder_df["folder"].unique():
        indices_to_keep = np.concat([np.random.choice(folder_df[folder_df["folder"] == f].index, size=min_folder_count), indices_to_keep])

    folder_df = folder_df.loc[indices_to_keep]
    folder_df.reset_index(drop=True, inplace=True)

if sampling_technique == "over":
    ros = RandomOverSampler(random_state=1368)

    # print how much each class will increase by (relative to its current size)
    max_folder = max(folder_df["folder"].value_counts())
    for folder, count in folder_df["folder"].value_counts().sort_values(ascending=True).items():
        print(f"{folder} will increase by {round((max_folder / count - 1) * 100, 2)}%")

    folder_df = pd.concat(ros.fit_resample(folder_df.drop("folder", axis=1), folder_df["folder"]), axis=1)
    # moves "folder" to other side of df but shouldn't affect anything

if sampling_technique == "median":
    # take the median value of folder counts
    # under sample all above the median
    # over smaple all below the median

    ros = RandomOverSampler(random_state=1368)
    median_folder_count = round(folder_df["folder"].value_counts().median())
    indices_to_keep = np.array([])

    print("median:", median_folder_count)

    for f in folder_df["folder"].unique():
        folder_length = len(folder_df[folder_df["folder"] == f])
        if folder_length > median_folder_count:
            indices_to_keep = np.concat([np.random.choice(folder_df[folder_df["folder"] == f].index, size=median_folder_count), indices_to_keep])
        else:
            indices_to_keep = np.concat([folder_df[folder_df["folder"] == f].index, indices_to_keep])
        
    folder_df = folder_df.loc[indices_to_keep]
    folder_df.reset_index(drop=True, inplace=True)
    
    folder_df = pd.concat(ros.fit_resample(folder_df.drop("folder", axis=1), folder_df["folder"]), axis=1)
# Out:
# median: 332

# %%
folder_df["folder"].value_counts().plot.bar(title=f"Value counts after {sampling_technique} sampling.")
# Out:
# <Axes: title={'center': 'Value counts after median sampling.'}, xlabel='folder'>

# %%
print("sound clips AFTER sampling:", len(folder_df))
# Out:
# sound clips AFTER sampling: 66400

# %%
# plot 5 random mel spectrograms
# checks for consistency in scaling and whatnot

reset_seed()

sample_spec_indices = random.sample(folder_df.index.tolist(), k=3)

for i in sample_spec_indices:
    row = folder_df.iloc[i]
    
    print(row["mel_spec_shape"])
    
    plt.figure()
    plt.imshow(row["mel_spec"])
    plt.title(f"Mel-Spectrogram of {'/'.join(row['file'].split('/')[-2:])}")
    plt.colorbar(format='%+2.0f dB')
    plt.show()

del row
# Out:
# (128, 125)
# (128, 125)
# (128, 125)

# %%
# input shape needs to be AxBxCxD
# A = list of files
# B = depth of each one (currently just 1, as it only contains 1 value. if colours are used then maybe up it to 3)
# CxD = input width/height (128x626 etc)
if "mel_spec" in folder_df.columns:
    print("step 1")
    x = folder_df["mel_spec"]
    print("step 2")
    folder_df.drop("mel_spec", axis=1, inplace=True)
    print("step 3")
    x = np.stack(x)
    print("step 4")
    x = torch.from_numpy(x)
    print("step 5")
    x = x.reshape(x.shape[0], 1, x.shape[1], x.shape[2])
    print("step 6")
    x = x.to(device)

print("step 7")
le = LabelEncoder()
print("step 8")
y = torch.LongTensor(le.fit_transform(folder_df["folder"]))
print("step 9")
y = y.to(device)
# Out:
# step 1
# step 2
# step 3
# step 4
# step 5
# step 6
# step 7
# step 8
# step 9

# %%
reset_seed()

x_train, x_test, y_train, y_test = train_test_split(x, y, shuffle=True, test_size=test_size, random_state=1368)

del x, y

# %%
# create machine learning model.

class TestModel(nn.Module):
    global folder_df

    def __init__(self, input_shape: torch.Size, dropout_rate: float = 0):
        super().__init__()

        total_output_classes = len(folder_df["folder"].unique())

        # input shape should be some list/tuple of length 4
        if len(input_shape) != 4: return Exception("Input shape is not AxBxCxD.")
        
        A = input_shape[0]
        B = input_shape[1]
        C = input_shape[2]
        D = input_shape[3]

        self.conv1 = nn.Conv2d(in_channels=B, out_channels=10, kernel_size=(3, 3))
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2)
        self.drop1 = nn.Dropout(p=dropout_rate)
        self.conv2 = nn.Conv2d(in_channels=10, out_channels=10, kernel_size=(3, 3))
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        self.drop2 = nn.Dropout(p=dropout_rate)
        self.flat = nn.Flatten()

        flatten_nodes = 10 * ((((C - 2) // 2) - 2) // 2) * ((((D - 2) // 2) - 2) // 2)
        
        self.norm = nn.BatchNorm1d(num_features=flatten_nodes)
        self.linear1 = nn.Linear(in_features=flatten_nodes, out_features=1024)
        self.linear2 = nn.Linear(in_features=1024, out_features=512)
        self.linear3 = nn.Linear(in_features=512, out_features=128) 
        self.output = nn.Linear(in_features=128, out_features=total_output_classes)

    def forward(self, x):
        # define calculations here
        x = self.relu1(self.conv1(x))
        x = self.pool1(x)
        x = self.drop1(x)
        x = self.relu2(self.conv2(x))
        x = self.pool2(x)
        x = self.drop2(x)
        x = self.flat(x)
        x = self.norm(x)
        x = self.linear1(x)
        x = self.linear2(x)
        x = self.linear3(x)
        x = self.output(x)

        return x

# %%
# model: the model to train
# loss_fn: the loss function to update weights
# optimizer: the optimiser function to affect rate of change
# epochs: number of epochs to train the model over
# batch_size: samples to train x_train and y_train to avoid memory issues
# save_best_to_file: save model with highest test accuracy to models/ folder.
# experimental: whether to end training after 5 consecutive runs of no higher test accuracy.
#       - training ends when either [epochs] epochs have been run, *OR* if 5 consecutive runs do not improve test accuracy from previous best.

def train_model(model, loss_fn, optimizer, epochs, batch_size, save_best_to_file = False, experimental = False):
    global x_train, y_train
    batch_indices = np.linspace(0, len(x_train), int(len(x_train) / batch_size), dtype="int")

    train_loss_hist = []
    train_acc_hist = []
    test_acc_hist = []

    best_test_acc = 0
    best_model = None

    experimental_counter = 0

    for epoch in range(1, epochs + 1):
        model.train()

        train_acc = 0
        
        for i in range(len(batch_indices) - 1):
            start_index = batch_indices[i]
            stop_index = batch_indices[i + 1]

            x_batch = x_train[start_index:stop_index]
            y_batch = y_train[start_index:stop_index]

            x_batch, y_batch = shuffle(x_batch, y_batch)

            y_pred = model(x_batch)
            loss = loss_fn(y_pred, y_batch)
            train_acc += sum(torch.argmax(y_pred, dim=1) == y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_acc = train_acc * 100 / len(y_train)

        model.eval()
        test_acc = sum(torch.argmax(model(x_test), dim=1) == y_test) * 100 / len(y_test)

        print(f"Epoch {epoch}: train loss = {loss:.04f}, train acc = {train_acc:.02f}%, test acc = {test_acc:.02f}% {"!!" if test_acc > best_test_acc else ""}")

        train_loss_hist.append(float(loss.cpu().detach().numpy()))
        train_acc_hist.append(float(train_acc.cpu().detach().numpy()))
        test_acc_hist.append(float(test_acc.cpu().detach().numpy()))

        if experimental:
            experimental_counter += 1

        if test_acc > best_test_acc:
            experimental_counter = 0
            best_test_acc = test_acc
            
            # overwrite best model with new best model
            best_model = copy.deepcopy(model.state_dict())

        if experimental_counter == experimental_counter_limit:
            print(f"Experimental Mode ended the training early, as the testing accuracy had not increased over {experimental_counter_limit} consecutive epochs.")
            break
        
    if save_best_to_file:
        model_save_path = "models/"
        if not os.path.exists(model_save_path): os.mkdir(model_save_path)
        file_number = len(os.listdir(model_save_path)) + 1
        file_name = f"best_model_{file_number:>03}"
        best_model_path = model_save_path + file_name + ".pth"

        torch.save(best_model, best_model_path)

    plt.figure(figsize=(12,8))
    pd.Series(train_acc_hist).plot.line(label="Train", color="blue")
    pd.Series(test_acc_hist).plot.line(label="Test", color="red")
    plt.legend()
    plt.ylim((0, 100))
    plt.yticks(np.arange(0, 101, 10))
    plt.title(f"Convolutional Neural Network on {len(folder_df)} sound clips over {len(folder_df["folder"].unique())} folders.")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.grid(axis="y")
    plt.show()

    return train_loss_hist, train_acc_hist, test_acc_hist, best_model

# %%
# to avoid extreme overfitting:
# - dropout rate between 0.2-0.5 seems good
# - learning rate around 0.001 provides best training rate without overfitting
# - train in larger batches, 64 upwards seems good
# - most seem to plateau around 200 epochs, maybe reduce to reduce total training time

reset_seed()

model = TestModel(input_shape=x_train.shape, dropout_rate=dropout_rate)
model = model.to(device)
loss_fn = nn.CrossEntropyLoss() # since we are classifying.
loss_fn = loss_fn.to(device)
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate) # adam has no momentum, but DOES have weight decay

print(sum(p.numel() for p in model.parameters() if p.requires_grad))

train_loss_hist, train_acc_hist, test_acc_hist, best_model = train_model(model, loss_fn, optimizer, epochs, batch_size, save_best_to_file=save_best_to_file, experimental=experimental)
# Out:
# 9544498
# Epoch 1: train loss = 3.9721, train acc = 9.42%, test acc = 9.58% !!
# Epoch 2: train loss = 3.3161, train acc = 21.66%, test acc = 19.33% !!
# Epoch 3: train loss = 3.0023, train acc = 29.84%, test acc = 27.67% !!
# Epoch 4: train loss = 2.7172, train acc = 35.95%, test acc = 32.74% !!
# Epoch 5: train loss = 2.5067, train acc = 40.52%, test acc = 37.99% !!
# Epoch 6: train loss = 2.3401, train acc = 43.77%, test acc = 41.47% !!
# Epoch 7: train loss = 2.1405, train acc = 47.62%, test acc = 43.21% !!
# Epoch 8: train loss = 2.0582, train acc = 49.62%, test acc = 45.90% !!
# Epoch 9: train loss = 1.9335, train acc = 52.21%, test acc = 47.88% !!
# Epoch 10: train loss = 1.8486, train acc = 54.07%, test acc = 49.86% !!
# Epoch 11: train loss = 1.7367, train acc = 55.78%, test acc = 51.13% !!
# Epoch 12: train loss = 1.6345, train acc = 57.03%, test acc = 52.94% !!
# Epoch 13: train loss = 1.4633, train acc = 58.54%, test acc = 54.69% !!
# Epoch 14: train loss = 1.5243, train acc = 59.82%, test acc = 55.37% !!
# Epoch 15: train loss = 1.4977, train acc = 61.06%, test acc = 56.71% !!
# Epoch 16: train loss = 1.5490, train acc = 61.95%, test acc = 56.34%
# Epoch 17: train loss = 1.3847, train acc = 63.07%, test acc = 57.42% !!
# Epoch 18: train loss = 1.3856, train acc = 63.82%, test acc = 57.97% !!
# Epoch 19: train loss = 1.3607, train acc = 64.43%, test acc = 58.66% !!
# Epoch 20: train loss = 1.3670, train acc = 65.63%, test acc = 59.30% !!
# Epoch 21: train loss = 1.4065, train acc = 65.95%, test acc = 59.77% !!
# Epoch 22: train loss = 1.2779, train acc = 66.60%, test acc = 60.76% !!
# Epoch 23: train loss = 1.3192, train acc = 67.10%, test acc = 59.98%
# Epoch 24: train loss = 1.2059, train acc = 67.30%, test acc = 60.82% !!
# Epoch 25: train loss = 1.2828, train acc = 68.18%, test acc = 61.03% !!
# Epoch 26: train loss = 1.2423, train acc = 68.33%, test acc = 62.06% !!
# Epoch 27: train loss = 1.1526, train acc = 68.82%, test acc = 61.67%
# Epoch 28: train loss = 1.1648, train acc = 69.50%, test acc = 61.79%
# Epoch 29: train loss = 1.1965, train acc = 69.93%, test acc = 62.36% !!
# Epoch 30: train loss = 1.1956, train acc = 70.46%, test acc = 62.15%
# Epoch 31: train loss = 1.1445, train acc = 70.28%, test acc = 61.55%
# Epoch 32: train loss = 1.1536, train acc = 70.79%, test acc = 62.51% !!
# Epoch 33: train loss = 1.1256, train acc = 70.95%, test acc = 63.18% !!
# Epoch 34: train loss = 1.0985, train acc = 71.64%, test acc = 62.83%
# Epoch 35: train loss = 1.1041, train acc = 71.80%, test acc = 62.88%
# Epoch 36: train loss = 1.0885, train acc = 72.18%, test acc = 63.40% !!
# Epoch 37: train loss = 1.1154, train acc = 72.34%, test acc = 63.54% !!
# Epoch 38: train loss = 1.0598, train acc = 72.87%, test acc = 63.81% !!
# Epoch 39: train loss = 1.0326, train acc = 73.00%, test acc = 63.19%
# Epoch 40: train loss = 1.0786, train acc = 73.28%, test acc = 61.20%
# Epoch 41: train loss = 0.9873, train acc = 73.22%, test acc = 62.42%
# Epoch 42: train loss = 1.0221, train acc = 73.40%, test acc = 64.07% !!
# Epoch 43: train loss = 0.9968, train acc = 73.96%, test acc = 64.19% !!
# Epoch 44: train loss = 0.9531, train acc = 73.69%, test acc = 63.86%
# Epoch 45: train loss = 0.9314, train acc = 74.02%, test acc = 64.39% !!
# Epoch 46: train loss = 0.9432, train acc = 74.66%, test acc = 64.88% !!
# Epoch 47: train loss = 0.9753, train acc = 74.55%, test acc = 64.61%
# Epoch 48: train loss = 0.9931, train acc = 74.82%, test acc = 64.53%
# Epoch 49: train loss = 0.9308, train acc = 75.00%, test acc = 64.82%
# Epoch 50: train loss = 0.9155, train acc = 75.36%, test acc = 64.59%
# Epoch 51: train loss = 0.9703, train acc = 75.02%, test acc = 65.00% !!
# Epoch 52: train loss = 0.9832, train acc = 75.36%, test acc = 64.68%
# Epoch 53: train loss = 0.9174, train acc = 75.47%, test acc = 64.37%
# Epoch 54: train loss = 0.9555, train acc = 75.57%, test acc = 64.84%
# Epoch 55: train loss = 0.8692, train acc = 75.82%, test acc = 64.56%
# Epoch 56: train loss = 0.9089, train acc = 75.57%, test acc = 65.23% !!
# Epoch 57: train loss = 0.9371, train acc = 75.98%, test acc = 64.61%
# Epoch 58: train loss = 0.9109, train acc = 76.13%, test acc = 65.41% !!
# Epoch 59: train loss = 0.8703, train acc = 76.60%, test acc = 65.37%
# Epoch 60: train loss = 0.8991, train acc = 76.33%, test acc = 64.51%
# Epoch 61: train loss = 0.8836, train acc = 76.04%, test acc = 65.80% !!
# Epoch 62: train loss = 0.8682, train acc = 76.62%, test acc = 65.29%
# Epoch 63: train loss = 0.9235, train acc = 77.03%, test acc = 64.41%
# Epoch 64: train loss = 0.8690, train acc = 76.46%, test acc = 65.60%
# Epoch 65: train loss = 0.8911, train acc = 76.83%, test acc = 65.85% !!
# Epoch 66: train loss = 0.9413, train acc = 76.63%, test acc = 65.24%
# Epoch 67: train loss = 0.8855, train acc = 76.84%, test acc = 65.67%
# Epoch 68: train loss = 0.8063, train acc = 77.18%, test acc = 65.38%
# Epoch 69: train loss = 0.8288, train acc = 77.40%, test acc = 65.86% !!
# Epoch 70: train loss = 0.8359, train acc = 77.27%, test acc = 65.42%
# Epoch 71: train loss = 0.8154, train acc = 77.44%, test acc = 65.82%
# Epoch 72: train loss = 0.8214, train acc = 77.90%, test acc = 65.86%
# Epoch 73: train loss = 0.8379, train acc = 77.88%, test acc = 65.66%
# Epoch 74: train loss = 0.7451, train acc = 77.92%, test acc = 66.05% !!
# Epoch 75: train loss = 0.9020, train acc = 77.72%, test acc = 65.38%
# Epoch 76: train loss = 0.9316, train acc = 77.80%, test acc = 64.89%
# Epoch 77: train loss = 0.8716, train acc = 78.14%, test acc = 65.58%
# Epoch 78: train loss = 0.8427, train acc = 77.91%, test acc = 65.38%
# Epoch 79: train loss = 0.8084, train acc = 78.07%, test acc = 66.15% !!
# Epoch 80: train loss = 0.8662, train acc = 78.34%, test acc = 66.42% !!
# Epoch 81: train loss = 0.7768, train acc = 78.51%, test acc = 66.15%
# Epoch 82: train loss = 0.7814, train acc = 78.60%, test acc = 66.40%
# Epoch 83: train loss = 0.7882, train acc = 78.30%, test acc = 65.99%
# Epoch 84: train loss = 0.8031, train acc = 78.48%, test acc = 66.22%
# Epoch 85: train loss = 0.8343, train acc = 79.00%, test acc = 66.64% !!
# Epoch 86: train loss = 0.7590, train acc = 79.16%, test acc = 66.80% !!
# Epoch 87: train loss = 0.7569, train acc = 78.79%, test acc = 65.75%
# Epoch 88: train loss = 0.7992, train acc = 78.92%, test acc = 66.90% !!
# Epoch 89: train loss = 0.8600, train acc = 78.85%, test acc = 65.96%
# Epoch 90: train loss = 0.7243, train acc = 79.21%, test acc = 66.60%
# Epoch 91: train loss = 0.8838, train acc = 79.10%, test acc = 67.23% !!
# Epoch 92: train loss = 0.7845, train acc = 79.62%, test acc = 66.57%
# Epoch 93: train loss = 0.8365, train acc = 79.17%, test acc = 66.76%
# Epoch 94: train loss = 0.8217, train acc = 79.23%, test acc = 66.90%
# Epoch 95: train loss = 0.6978, train acc = 79.83%, test acc = 66.68%
# Epoch 96: train loss = 0.7680, train acc = 79.49%, test acc = 66.69%
# Epoch 97: train loss = 0.7820, train acc = 79.62%, test acc = 66.60%
# Epoch 98: train loss = 0.7270, train acc = 79.81%, test acc = 66.63%
# Epoch 99: train loss = 0.7062, train acc = 79.86%, test acc = 67.06%
# Epoch 100: train loss = 0.7434, train acc = 79.89%, test acc = 66.64%
# Epoch 101: train loss = 0.8048, train acc = 79.94%, test acc = 66.62%
# Epoch 102: train loss = 0.7167, train acc = 79.95%, test acc = 67.05%
# Epoch 103: train loss = 0.7311, train acc = 79.99%, test acc = 67.14%
# Epoch 104: train loss = 0.6893, train acc = 79.87%, test acc = 66.84%
# Epoch 105: train loss = 0.7411, train acc = 79.92%, test acc = 67.22%
# Epoch 106: train loss = 0.7966, train acc = 80.17%, test acc = 67.45% !!
# Epoch 107: train loss = 0.8047, train acc = 80.20%, test acc = 66.29%
# Epoch 108: train loss = 0.7852, train acc = 80.30%, test acc = 66.78%
# Epoch 109: train loss = 0.7190, train acc = 80.60%, test acc = 66.66%
# Epoch 110: train loss = 0.8277, train acc = 80.24%, test acc = 66.18%
# Epoch 111: train loss = 0.7595, train acc = 80.03%, test acc = 67.03%
# Epoch 112: train loss = 0.7810, train acc = 80.31%, test acc = 66.72%
# Epoch 113: train loss = 0.7233, train acc = 80.63%, test acc = 67.12%
# Epoch 114: train loss = 0.7639, train acc = 80.63%, test acc = 67.39%
# Epoch 115: train loss = 0.7274, train acc = 80.44%, test acc = 67.27%
# Epoch 116: train loss = 0.6740, train acc = 80.60%, test acc = 67.31%
# Epoch 117: train loss = 0.7070, train acc = 80.95%, test acc = 67.12%
# Epoch 118: train loss = 0.7163, train acc = 80.99%, test acc = 67.10%
# Epoch 119: train loss = 0.6736, train acc = 80.68%, test acc = 67.29%
# Epoch 120: train loss = 0.7020, train acc = 80.67%, test acc = 67.12%
# Epoch 121: train loss = 0.6857, train acc = 80.98%, test acc = 67.71% !!
# Epoch 122: train loss = 0.7092, train acc = 81.03%, test acc = 67.33%
# Epoch 123: train loss = 0.6918, train acc = 81.39%, test acc = 67.37%
# Epoch 124: train loss = 0.6727, train acc = 81.36%, test acc = 67.70%
# Epoch 125: train loss = 0.6838, train acc = 81.54%, test acc = 67.41%
# Epoch 126: train loss = 0.6695, train acc = 81.11%, test acc = 66.73%
# Epoch 127: train loss = 0.7395, train acc = 81.30%, test acc = 67.29%
# Epoch 128: train loss = 0.6261, train acc = 81.03%, test acc = 67.43%
# Epoch 129: train loss = 0.6973, train acc = 81.67%, test acc = 67.55%
# Epoch 130: train loss = 0.7137, train acc = 81.29%, test acc = 67.23%
# Epoch 131: train loss = 0.6436, train acc = 81.40%, test acc = 67.59%
# Epoch 132: train loss = 0.7344, train acc = 81.58%, test acc = 68.03% !!
# Epoch 133: train loss = 0.6834, train acc = 81.78%, test acc = 67.45%
# Epoch 134: train loss = 0.7133, train acc = 81.94%, test acc = 67.88%
# Epoch 135: train loss = 0.6848, train acc = 81.47%, test acc = 67.28%
# Epoch 136: train loss = 0.7015, train acc = 81.67%, test acc = 67.92%
# Epoch 137: train loss = 0.7142, train acc = 81.78%, test acc = 68.00%
# Epoch 138: train loss = 0.7008, train acc = 81.89%, test acc = 67.39%
# Epoch 139: train loss = 0.7008, train acc = 81.99%, test acc = 67.73%
# Epoch 140: train loss = 0.7020, train acc = 81.78%, test acc = 67.27%
# Epoch 141: train loss = 0.6546, train acc = 81.41%, test acc = 66.91%
# Epoch 142: train loss = 0.6770, train acc = 81.90%, test acc = 67.74%
# Epoch 143: train loss = 0.6973, train acc = 82.01%, test acc = 67.89%
# Epoch 144: train loss = 0.6418, train acc = 81.63%, test acc = 67.39%
# Epoch 145: train loss = 0.6222, train acc = 82.15%, test acc = 67.88%
# Epoch 146: train loss = 0.7105, train acc = 81.93%, test acc = 67.67%
# Epoch 147: train loss = 0.6123, train acc = 82.21%, test acc = 68.11% !!
# Epoch 148: train loss = 0.6573, train acc = 82.00%, test acc = 67.85%
# Epoch 149: train loss = 0.6210, train acc = 82.41%, test acc = 68.19% !!
# Epoch 150: train loss = 0.6491, train acc = 81.91%, test acc = 67.82%
# Epoch 151: train loss = 0.6235, train acc = 82.40%, test acc = 67.60%
# Epoch 152: train loss = 0.6787, train acc = 82.14%, test acc = 68.19%
# Epoch 153: train loss = 0.6034, train acc = 82.33%, test acc = 67.47%
# Epoch 154: train loss = 0.6757, train acc = 82.12%, test acc = 67.75%
# Epoch 155: train loss = 0.5403, train acc = 82.68%, test acc = 67.92%
# Epoch 156: train loss = 0.6311, train acc = 82.65%, test acc = 67.91%
# Epoch 157: train loss = 0.6932, train acc = 82.57%, test acc = 68.40% !!
# Epoch 158: train loss = 0.6344, train acc = 82.81%, test acc = 67.94%
# Epoch 159: train loss = 0.6513, train acc = 82.87%, test acc = 67.91%
# Epoch 160: train loss = 0.7102, train acc = 82.83%, test acc = 68.13%
# Epoch 161: train loss = 0.6230, train acc = 82.85%, test acc = 67.79%
# Epoch 162: train loss = 0.5928, train acc = 82.64%, test acc = 67.39%
# Epoch 163: train loss = 0.6158, train acc = 82.63%, test acc = 67.76%
# Epoch 164: train loss = 0.6335, train acc = 82.61%, test acc = 67.82%
# Epoch 165: train loss = 0.6591, train acc = 82.82%, test acc = 68.27%
# Epoch 166: train loss = 0.6244, train acc = 82.88%, test acc = 68.63% !!
# Epoch 167: train loss = 0.6533, train acc = 83.08%, test acc = 68.09%
# Epoch 168: train loss = 0.5555, train acc = 82.91%, test acc = 68.17%
# Epoch 169: train loss = 0.5996, train acc = 83.14%, test acc = 67.89%
# Epoch 170: train loss = 0.6355, train acc = 83.10%, test acc = 67.94%
# Epoch 171: train loss = 0.6475, train acc = 83.12%, test acc = 68.28%
# Epoch 172: train loss = 0.5368, train acc = 83.12%, test acc = 67.85%
# Epoch 173: train loss = 0.6502, train acc = 82.94%, test acc = 67.45%
# Epoch 174: train loss = 0.6599, train acc = 82.76%, test acc = 67.87%
# Epoch 175: train loss = 0.6891, train acc = 83.13%, test acc = 67.94%
# Epoch 176: train loss = 0.6429, train acc = 82.91%, test acc = 68.03%
# Epoch 177: train loss = 0.7112, train acc = 82.85%, test acc = 67.80%
# Epoch 178: train loss = 0.5640, train acc = 83.14%, test acc = 68.23%
# Epoch 179: train loss = 0.5688, train acc = 83.21%, test acc = 67.90%
# Epoch 180: train loss = 0.6221, train acc = 83.21%, test acc = 67.91%
# Epoch 181: train loss = 0.5605, train acc = 82.91%, test acc = 68.55%
# Epoch 182: train loss = 0.5500, train acc = 83.25%, test acc = 68.14%
# Epoch 183: train loss = 0.5991, train acc = 83.36%, test acc = 68.66% !!
# Epoch 184: train loss = 0.6667, train acc = 83.34%, test acc = 68.15%
# Epoch 185: train loss = 0.6633, train acc = 83.28%, test acc = 68.19%
# Epoch 186: train loss = 0.5932, train acc = 83.63%, test acc = 67.93%
# Epoch 187: train loss = 0.6375, train acc = 83.51%, test acc = 68.63%
# Epoch 188: train loss = 0.6245, train acc = 83.23%, test acc = 68.05%
# Epoch 189: train loss = 0.6394, train acc = 83.29%, test acc = 68.21%
# Epoch 190: train loss = 0.6429, train acc = 83.65%, test acc = 67.52%
# Epoch 191: train loss = 0.5563, train acc = 83.60%, test acc = 68.09%
# Epoch 192: train loss = 0.6676, train acc = 83.82%, test acc = 67.24%
# Epoch 193: train loss = 0.5702, train acc = 83.41%, test acc = 68.12%
# Epoch 194: train loss = 0.6326, train acc = 83.74%, test acc = 68.05%
# Epoch 195: train loss = 0.6943, train acc = 83.33%, test acc = 67.52%
# Epoch 196: train loss = 0.6037, train acc = 83.54%, test acc = 68.34%
# Epoch 197: train loss = 0.5885, train acc = 83.69%, test acc = 68.19%
# Epoch 198: train loss = 0.6332, train acc = 83.89%, test acc = 67.71%
# Epoch 199: train loss = 0.6338, train acc = 83.44%, test acc = 68.41%
# Epoch 200: train loss = 0.5301, train acc = 83.69%, test acc = 68.37%
# Epoch 201: train loss = 0.5984, train acc = 83.93%, test acc = 68.80% !!
# Epoch 202: train loss = 0.5814, train acc = 83.86%, test acc = 68.22%
# Epoch 203: train loss = 0.5466, train acc = 83.90%, test acc = 68.60%
# Epoch 204: train loss = 0.5482, train acc = 83.99%, test acc = 68.81% !!
# Epoch 205: train loss = 0.5587, train acc = 83.53%, test acc = 68.45%
# Epoch 206: train loss = 0.5863, train acc = 83.31%, test acc = 68.14%
# Epoch 207: train loss = 0.6224, train acc = 84.07%, test acc = 68.15%
# Epoch 208: train loss = 0.5773, train acc = 84.13%, test acc = 68.54%
# Epoch 209: train loss = 0.6574, train acc = 83.36%, test acc = 68.00%
# Epoch 210: train loss = 0.6328, train acc = 84.02%, test acc = 67.98%
# Epoch 211: train loss = 0.5528, train acc = 83.99%, test acc = 68.04%
# Epoch 212: train loss = 0.5549, train acc = 84.08%, test acc = 68.90% !!
# Epoch 213: train loss = 0.5767, train acc = 84.06%, test acc = 68.01%
# Epoch 214: train loss = 0.6057, train acc = 84.25%, test acc = 68.34%
# Epoch 215: train loss = 0.5892, train acc = 84.24%, test acc = 68.32%
# Epoch 216: train loss = 0.6898, train acc = 84.08%, test acc = 68.37%
# Epoch 217: train loss = 0.5205, train acc = 84.19%, test acc = 68.72%
# Epoch 218: train loss = 0.6223, train acc = 83.79%, test acc = 68.91% !!
# Epoch 219: train loss = 0.6124, train acc = 84.30%, test acc = 67.94%
# Epoch 220: train loss = 0.5509, train acc = 84.44%, test acc = 68.29%
# Epoch 221: train loss = 0.5736, train acc = 84.07%, test acc = 68.46%
# Epoch 222: train loss = 0.6062, train acc = 84.35%, test acc = 68.55%
# Epoch 223: train loss = 0.5901, train acc = 84.06%, test acc = 68.58%
# Epoch 224: train loss = 0.5394, train acc = 84.39%, test acc = 68.41%
# Epoch 225: train loss = 0.6154, train acc = 84.29%, test acc = 67.97%
# Epoch 226: train loss = 0.5801, train acc = 83.92%, test acc = 68.46%
# Epoch 227: train loss = 0.5597, train acc = 84.35%, test acc = 68.28%
# Epoch 228: train loss = 0.5616, train acc = 84.39%, test acc = 68.71%
# Epoch 229: train loss = 0.5925, train acc = 84.51%, test acc = 68.44%
# Epoch 230: train loss = 0.5638, train acc = 84.24%, test acc = 68.45%
# Epoch 231: train loss = 0.6060, train acc = 84.51%, test acc = 68.81%
# Epoch 232: train loss = 0.5724, train acc = 84.48%, test acc = 68.64%
# Epoch 233: train loss = 0.6508, train acc = 84.90%, test acc = 68.53%
# Epoch 234: train loss = 0.4967, train acc = 84.69%, test acc = 69.31% !!
# Epoch 235: train loss = 0.6321, train acc = 84.77%, test acc = 68.68%
# Epoch 236: train loss = 0.5968, train acc = 84.55%, test acc = 68.56%
# Epoch 237: train loss = 0.4876, train acc = 84.81%, test acc = 68.98%
# Epoch 238: train loss = 0.5949, train acc = 84.76%, test acc = 68.70%
# Epoch 239: train loss = 0.5159, train acc = 84.60%, test acc = 68.73%
# Epoch 240: train loss = 0.5683, train acc = 84.58%, test acc = 68.75%
# Epoch 241: train loss = 0.5318, train acc = 84.32%, test acc = 68.78%
# Epoch 242: train loss = 0.5245, train acc = 84.42%, test acc = 68.90%
# Epoch 243: train loss = 0.5260, train acc = 84.43%, test acc = 69.10%
# Epoch 244: train loss = 0.5584, train acc = 84.55%, test acc = 68.93%
# Epoch 245: train loss = 0.4784, train acc = 85.19%, test acc = 69.23%
# Epoch 246: train loss = 0.6638, train acc = 85.12%, test acc = 68.73%
# Epoch 247: train loss = 0.5021, train acc = 85.04%, test acc = 69.00%
# Epoch 248: train loss = 0.5769, train acc = 85.04%, test acc = 68.56%
# Epoch 249: train loss = 0.6155, train acc = 84.83%, test acc = 68.65%
# Epoch 250: train loss = 0.5932, train acc = 84.71%, test acc = 68.05%
# Epoch 251: train loss = 0.5739, train acc = 84.39%, test acc = 69.03%
# Epoch 252: train loss = 0.5464, train acc = 84.92%, test acc = 68.61%
# Epoch 253: train loss = 0.5722, train acc = 84.68%, test acc = 68.23%
# Epoch 254: train loss = 0.5708, train acc = 85.08%, test acc = 68.30%
# Epoch 255: train loss = 0.5557, train acc = 84.80%, test acc = 68.55%
# Epoch 256: train loss = 0.5166, train acc = 85.40%, test acc = 69.09%
# Epoch 257: train loss = 0.4875, train acc = 85.14%, test acc = 68.40%
# Epoch 258: train loss = 0.5404, train acc = 85.16%, test acc = 69.01%
# Epoch 259: train loss = 0.5760, train acc = 85.45%, test acc = 69.03%
# Epoch 260: train loss = 0.5674, train acc = 85.28%, test acc = 68.53%
# Epoch 261: train loss = 0.5924, train acc = 85.19%, test acc = 68.92%
# Epoch 262: train loss = 0.5802, train acc = 84.71%, test acc = 68.61%
# Epoch 263: train loss = 0.5440, train acc = 85.10%, test acc = 68.36%
# Epoch 264: train loss = 0.5311, train acc = 84.76%, test acc = 68.99%
# Epoch 265: train loss = 0.5576, train acc = 85.05%, test acc = 68.15%
# Epoch 266: train loss = 0.5456, train acc = 85.04%, test acc = 68.06%
# Epoch 267: train loss = 0.5331, train acc = 85.07%, test acc = 68.53%
# Epoch 268: train loss = 0.5097, train acc = 85.33%, test acc = 68.50%
# Epoch 269: train loss = 0.4596, train acc = 85.47%, test acc = 68.40%
# Epoch 270: train loss = 0.5047, train acc = 85.65%, test acc = 68.77%
# Epoch 271: train loss = 0.6194, train acc = 85.15%, test acc = 68.67%
# Epoch 272: train loss = 0.4920, train acc = 84.98%, test acc = 68.76%
# Epoch 273: train loss = 0.6918, train acc = 85.34%, test acc = 68.67%
# Epoch 274: train loss = 0.5711, train acc = 85.59%, test acc = 68.70%
# Epoch 275: train loss = 0.5322, train acc = 85.17%, test acc = 68.72%
# Epoch 276: train loss = 0.5213, train acc = 85.39%, test acc = 69.24%
# Epoch 277: train loss = 0.5709, train acc = 85.34%, test acc = 69.07%
# Epoch 278: train loss = 0.5554, train acc = 85.70%, test acc = 69.24%
# Epoch 279: train loss = 0.5405, train acc = 85.40%, test acc = 68.98%
# Epoch 280: train loss = 0.5770, train acc = 85.36%, test acc = 68.96%
# Epoch 281: train loss = 0.4993, train acc = 85.75%, test acc = 68.86%
# Epoch 282: train loss = 0.5597, train acc = 85.25%, test acc = 69.30%
# Epoch 283: train loss = 0.6058, train acc = 85.41%, test acc = 69.21%
# Epoch 284: train loss = 0.5147, train acc = 85.38%, test acc = 68.93%
# Epoch 285: train loss = 0.5108, train acc = 85.43%, test acc = 69.04%
# Epoch 286: train loss = 0.4641, train acc = 85.41%, test acc = 69.24%
# Epoch 287: train loss = 0.5408, train acc = 85.53%, test acc = 69.34% !!
# Epoch 288: train loss = 0.4651, train acc = 85.64%, test acc = 68.58%
# Epoch 289: train loss = 0.5499, train acc = 85.54%, test acc = 68.53%
# Epoch 290: train loss = 0.5302, train acc = 85.65%, test acc = 68.83%
# Epoch 291: train loss = 0.5860, train acc = 85.65%, test acc = 69.78% !!
# Epoch 292: train loss = 0.5676, train acc = 85.81%, test acc = 69.02%
# Epoch 293: train loss = 0.5377, train acc = 85.74%, test acc = 68.94%
# Epoch 294: train loss = 0.4891, train acc = 85.86%, test acc = 68.92%
# Epoch 295: train loss = 0.5026, train acc = 85.78%, test acc = 68.80%
# Epoch 296: train loss = 0.5449, train acc = 85.43%, test acc = 68.77%
# Epoch 297: train loss = 0.5628, train acc = 85.51%, test acc = 69.36%
# Epoch 298: train loss = 0.5270, train acc = 85.58%, test acc = 68.87%
# Epoch 299: train loss = 0.4805, train acc = 86.06%, test acc = 68.98%
# Epoch 300: train loss = 0.5718, train acc = 85.76%, test acc = 69.14%
# Epoch 301: train loss = 0.5637, train acc = 85.31%, test acc = 68.73%
# Epoch 302: train loss = 0.4785, train acc = 85.74%, test acc = 68.80%
# Epoch 303: train loss = 0.4786, train acc = 85.86%, test acc = 68.77%
# Epoch 304: train loss = 0.5150, train acc = 85.89%, test acc = 68.98%
# Epoch 305: train loss = 0.5883, train acc = 85.92%, test acc = 69.10%
# Epoch 306: train loss = 0.5291, train acc = 85.77%, test acc = 68.97%
# Epoch 307: train loss = 0.5093, train acc = 85.50%, test acc = 68.89%
# Epoch 308: train loss = 0.4871, train acc = 85.79%, test acc = 68.58%
# Epoch 309: train loss = 0.5745, train acc = 85.79%, test acc = 69.27%
# Epoch 310: train loss = 0.4649, train acc = 85.68%, test acc = 69.27%
# Epoch 311: train loss = 0.5537, train acc = 85.92%, test acc = 68.64%
# Epoch 312: train loss = 0.5068, train acc = 86.04%, test acc = 69.04%
# Epoch 313: train loss = 0.5250, train acc = 86.51%, test acc = 68.96%
# Epoch 314: train loss = 0.5734, train acc = 85.79%, test acc = 69.23%
# Epoch 315: train loss = 0.5851, train acc = 85.99%, test acc = 69.36%
# Epoch 316: train loss = 0.5015, train acc = 86.35%, test acc = 69.20%
# Epoch 317: train loss = 0.5125, train acc = 86.04%, test acc = 69.34%
# Epoch 318: train loss = 0.5262, train acc = 86.03%, test acc = 69.42%
# Epoch 319: train loss = 0.5069, train acc = 86.22%, test acc = 68.93%
# Epoch 320: train loss = 0.5325, train acc = 86.09%, test acc = 69.26%
# Epoch 321: train loss = 0.4975, train acc = 86.57%, test acc = 69.17%
# Epoch 322: train loss = 0.5059, train acc = 86.03%, test acc = 69.01%
# Epoch 323: train loss = 0.5178, train acc = 85.78%, test acc = 68.85%
# Epoch 324: train loss = 0.4727, train acc = 86.10%, test acc = 68.98%
# Epoch 325: train loss = 0.5381, train acc = 86.33%, test acc = 69.12%
# Epoch 326: train loss = 0.5715, train acc = 86.13%, test acc = 68.92%
# Epoch 327: train loss = 0.4694, train acc = 86.32%, test acc = 69.05%
# Epoch 328: train loss = 0.5071, train acc = 86.42%, test acc = 68.95%
# Epoch 329: train loss = 0.4698, train acc = 86.08%, test acc = 69.68%
# Epoch 330: train loss = 0.5221, train acc = 86.10%, test acc = 68.61%
# Epoch 331: train loss = 0.4204, train acc = 86.66%, test acc = 69.56%
# Epoch 332: train loss = 0.4569, train acc = 86.45%, test acc = 68.94%
# Epoch 333: train loss = 0.5237, train acc = 86.39%, test acc = 68.70%
# Epoch 334: train loss = 0.5359, train acc = 86.10%, test acc = 68.76%
# Epoch 335: train loss = 0.4751, train acc = 86.10%, test acc = 69.50%
# Epoch 336: train loss = 0.4896, train acc = 86.19%, test acc = 68.72%
# Epoch 337: train loss = 0.4201, train acc = 86.41%, test acc = 68.77%
# Epoch 338: train loss = 0.5256, train acc = 86.21%, test acc = 69.12%
# Epoch 339: train loss = 0.4580, train acc = 86.62%, test acc = 69.55%
# Epoch 340: train loss = 0.5020, train acc = 86.32%, test acc = 68.91%
# Epoch 341: train loss = 0.4999, train acc = 86.30%, test acc = 68.63%
# Epoch 342: train loss = 0.4595, train acc = 86.13%, test acc = 69.10%
# Epoch 343: train loss = 0.5769, train acc = 86.55%, test acc = 69.42%
# Epoch 344: train loss = 0.4471, train acc = 86.71%, test acc = 69.50%
# Epoch 345: train loss = 0.4324, train acc = 86.66%, test acc = 69.89% !!
# Epoch 346: train loss = 0.4629, train acc = 86.55%, test acc = 69.10%
# Epoch 347: train loss = 0.4365, train acc = 86.64%, test acc = 69.17%
# Epoch 348: train loss = 0.4628, train acc = 85.67%, test acc = 69.22%
# Epoch 349: train loss = 0.5702, train acc = 86.26%, test acc = 68.91%
# Epoch 350: train loss = 0.5049, train acc = 86.65%, test acc = 69.56%
# Epoch 351: train loss = 0.5060, train acc = 86.62%, test acc = 69.59%
# Epoch 352: train loss = 0.4785, train acc = 86.87%, test acc = 69.54%
# Epoch 353: train loss = 0.5386, train acc = 86.59%, test acc = 68.94%
# Epoch 354: train loss = 0.4944, train acc = 86.50%, test acc = 69.75%
# Epoch 355: train loss = 0.5076, train acc = 86.82%, test acc = 69.71%
# Epoch 356: train loss = 0.5849, train acc = 86.33%, test acc = 68.90%
# Epoch 357: train loss = 0.5167, train acc = 86.50%, test acc = 69.28%
# Epoch 358: train loss = 0.5054, train acc = 86.81%, test acc = 68.95%
# Epoch 359: train loss = 0.5599, train acc = 86.59%, test acc = 69.35%
# Epoch 360: train loss = 0.5312, train acc = 86.19%, test acc = 69.07%
# Epoch 361: train loss = 0.4536, train acc = 86.56%, test acc = 69.19%
# Epoch 362: train loss = 0.5732, train acc = 86.43%, test acc = 69.21%
# Epoch 363: train loss = 0.4808, train acc = 86.87%, test acc = 69.01%
# Epoch 364: train loss = 0.5176, train acc = 86.65%, test acc = 69.36%
# Epoch 365: train loss = 0.5173, train acc = 86.56%, test acc = 69.74%
# Epoch 366: train loss = 0.4447, train acc = 87.07%, test acc = 69.54%
# Epoch 367: train loss = 0.4322, train acc = 86.60%, test acc = 69.40%
# Epoch 368: train loss = 0.5484, train acc = 86.56%, test acc = 69.13%
# Epoch 369: train loss = 0.4588, train acc = 86.63%, test acc = 69.17%
# Epoch 370: train loss = 0.4348, train acc = 87.06%, test acc = 69.30%
# Epoch 371: train loss = 0.4719, train acc = 86.39%, test acc = 68.98%
# Epoch 372: train loss = 0.4853, train acc = 86.89%, test acc = 69.20%
# Epoch 373: train loss = 0.4353, train acc = 87.09%, test acc = 69.20%
# Epoch 374: train loss = 0.4970, train acc = 86.86%, test acc = 69.47%
# Epoch 375: train loss = 0.4861, train acc = 86.84%, test acc = 69.74%
# Epoch 376: train loss = 0.4073, train acc = 87.02%, test acc = 69.21%
# Epoch 377: train loss = 0.4778, train acc = 86.83%, test acc = 69.33%
# Epoch 378: train loss = 0.3835, train acc = 87.04%, test acc = 69.73%
# Epoch 379: train loss = 0.5026, train acc = 86.73%, test acc = 69.84%
# Epoch 380: train loss = 0.4893, train acc = 87.14%, test acc = 69.42%
# Epoch 381: train loss = 0.4817, train acc = 86.73%, test acc = 69.33%
# Epoch 382: train loss = 0.4742, train acc = 86.87%, test acc = 69.12%
# Epoch 383: train loss = 0.4831, train acc = 86.68%, test acc = 69.93% !!
# Epoch 384: train loss = 0.4888, train acc = 86.37%, test acc = 69.02%
# Epoch 385: train loss = 0.4853, train acc = 86.60%, test acc = 69.85%
# Epoch 386: train loss = 0.4462, train acc = 86.39%, test acc = 69.16%
# Epoch 387: train loss = 0.4947, train acc = 87.00%, test acc = 69.63%
# Epoch 388: train loss = 0.4156, train acc = 87.19%, test acc = 69.65%
# Epoch 389: train loss = 0.4869, train acc = 87.08%, test acc = 69.63%
# Epoch 390: train loss = 0.3914, train acc = 87.13%, test acc = 68.58%
# Epoch 391: train loss = 0.4638, train acc = 86.89%, test acc = 69.20%
# Epoch 392: train loss = 0.4941, train acc = 87.26%, test acc = 69.25%
# Epoch 393: train loss = 0.4588, train acc = 87.32%, test acc = 69.46%
# Epoch 394: train loss = 0.4529, train acc = 87.30%, test acc = 69.75%
# Epoch 395: train loss = 0.4486, train acc = 86.96%, test acc = 69.44%
# Epoch 396: train loss = 0.5666, train acc = 87.15%, test acc = 69.48%
# Epoch 397: train loss = 0.4904, train acc = 87.18%, test acc = 70.02% !!
# Epoch 398: train loss = 0.4935, train acc = 87.29%, test acc = 69.81%
# Epoch 399: train loss = 0.4444, train acc = 86.55%, test acc = 69.03%
# Epoch 400: train loss = 0.4963, train acc = 86.71%, test acc = 69.70%
# Epoch 401: train loss = 0.4491, train acc = 87.48%, test acc = 69.62%
# Epoch 402: train loss = 0.5064, train acc = 87.37%, test acc = 69.67%
# Epoch 403: train loss = 0.4577, train acc = 87.32%, test acc = 69.39%
# Epoch 404: train loss = 0.4830, train acc = 87.41%, test acc = 69.46%
# Epoch 405: train loss = 0.4904, train acc = 87.00%, test acc = 69.04%
# Epoch 406: train loss = 0.4701, train acc = 87.34%, test acc = 69.59%
# Epoch 407: train loss = 0.4949, train acc = 87.48%, test acc = 69.18%
# Epoch 408: train loss = 0.5091, train acc = 87.47%, test acc = 69.73%
# Epoch 409: train loss = 0.5157, train acc = 87.58%, test acc = 69.62%
# Epoch 410: train loss = 0.4466, train acc = 87.24%, test acc = 69.43%
# Epoch 411: train loss = 0.4452, train acc = 87.20%, test acc = 68.98%
# Epoch 412: train loss = 0.4505, train acc = 87.24%, test acc = 70.24% !!
# Epoch 413: train loss = 0.4203, train acc = 87.26%, test acc = 69.19%
# Epoch 414: train loss = 0.4749, train acc = 87.05%, test acc = 69.28%
# Epoch 415: train loss = 0.4766, train acc = 87.42%, test acc = 68.92%
# Epoch 416: train loss = 0.4562, train acc = 87.29%, test acc = 69.71%
# Epoch 417: train loss = 0.4545, train acc = 87.34%, test acc = 69.15%
# Epoch 418: train loss = 0.4575, train acc = 87.58%, test acc = 69.68%
# Epoch 419: train loss = 0.4992, train acc = 87.42%, test acc = 69.46%
# Epoch 420: train loss = 0.4465, train acc = 87.58%, test acc = 69.95%
# Epoch 421: train loss = 0.4804, train acc = 87.55%, test acc = 69.41%
# Epoch 422: train loss = 0.3996, train acc = 87.35%, test acc = 69.74%
# Epoch 423: train loss = 0.5038, train acc = 87.46%, test acc = 69.38%
# Epoch 424: train loss = 0.4756, train acc = 87.39%, test acc = 69.56%
# Epoch 425: train loss = 0.4108, train acc = 87.58%, test acc = 69.80%
# Epoch 426: train loss = 0.5191, train acc = 87.45%, test acc = 69.54%
# Epoch 427: train loss = 0.4335, train acc = 87.45%, test acc = 69.63%
# Epoch 428: train loss = 0.4471, train acc = 87.44%, test acc = 69.31%
# Epoch 429: train loss = 0.5706, train acc = 87.40%, test acc = 69.26%
# Epoch 430: train loss = 0.4523, train acc = 86.97%, test acc = 69.59%
# Epoch 431: train loss = 0.4966, train acc = 87.41%, test acc = 69.56%
# Epoch 432: train loss = 0.3678, train acc = 87.51%, test acc = 69.33%
# Epoch 433: train loss = 0.4280, train acc = 87.75%, test acc = 69.98%
# Epoch 434: train loss = 0.3868, train acc = 87.90%, test acc = 70.05%
# Epoch 435: train loss = 0.5217, train acc = 87.53%, test acc = 69.52%
# Epoch 436: train loss = 0.4689, train acc = 87.76%, test acc = 69.86%
# Epoch 437: train loss = 0.4893, train acc = 86.76%, test acc = 68.66%
# Epoch 438: train loss = 0.4601, train acc = 87.29%, test acc = 69.27%
# Epoch 439: train loss = 0.4672, train acc = 87.61%, test acc = 69.29%
# Epoch 440: train loss = 0.4704, train acc = 87.65%, test acc = 69.92%
# Epoch 441: train loss = 0.3779, train acc = 88.03%, test acc = 69.52%
# Epoch 442: train loss = 0.4409, train acc = 87.63%, test acc = 69.80%
# Epoch 443: train loss = 0.3893, train acc = 87.58%, test acc = 69.60%
# Epoch 444: train loss = 0.4683, train acc = 87.74%, test acc = 70.05%
# Epoch 445: train loss = 0.4454, train acc = 87.75%, test acc = 68.87%
# Epoch 446: train loss = 0.4065, train acc = 88.03%, test acc = 70.11%
# Epoch 447: train loss = 0.3880, train acc = 87.96%, test acc = 69.74%
# Epoch 448: train loss = 0.4353, train acc = 87.90%, test acc = 69.77%
# Epoch 449: train loss = 0.4429, train acc = 87.68%, test acc = 69.52%
# Epoch 450: train loss = 0.3918, train acc = 87.55%, test acc = 69.41%
# Epoch 451: train loss = 0.5043, train acc = 87.71%, test acc = 69.09%
# Epoch 452: train loss = 0.4167, train acc = 87.63%, test acc = 69.50%
# Epoch 453: train loss = 0.4560, train acc = 87.91%, test acc = 69.73%
# Epoch 454: train loss = 0.4466, train acc = 87.83%, test acc = 69.48%
# Epoch 455: train loss = 0.4508, train acc = 87.71%, test acc = 69.71%
# Epoch 456: train loss = 0.4522, train acc = 87.73%, test acc = 69.72%
# Epoch 457: train loss = 0.4649, train acc = 88.05%, test acc = 70.11%
# Epoch 458: train loss = 0.4169, train acc = 87.57%, test acc = 69.59%
# Epoch 459: train loss = 0.4833, train acc = 87.87%, test acc = 69.68%
# Epoch 460: train loss = 0.4669, train acc = 87.76%, test acc = 69.68%
# Epoch 461: train loss = 0.4818, train acc = 87.50%, test acc = 70.13%
# Epoch 462: train loss = 0.4685, train acc = 87.73%, test acc = 69.80%
# Epoch 463: train loss = 0.4298, train acc = 88.14%, test acc = 69.71%
# Epoch 464: train loss = 0.4233, train acc = 88.17%, test acc = 70.29% !!
# Epoch 465: train loss = 0.4424, train acc = 87.80%, test acc = 69.63%
# Epoch 466: train loss = 0.4299, train acc = 88.02%, test acc = 69.68%
# Epoch 467: train loss = 0.4615, train acc = 87.74%, test acc = 69.50%
# Epoch 468: train loss = 0.4714, train acc = 88.09%, test acc = 69.92%
# Epoch 469: train loss = 0.3803, train acc = 87.72%, test acc = 69.40%
# Epoch 470: train loss = 0.4401, train acc = 87.81%, test acc = 69.81%
# Epoch 471: train loss = 0.4651, train acc = 87.83%, test acc = 69.48%
# Epoch 472: train loss = 0.4685, train acc = 87.84%, test acc = 69.13%
# Epoch 473: train loss = 0.4251, train acc = 88.16%, test acc = 69.91%
# Epoch 474: train loss = 0.4048, train acc = 88.35%, test acc = 69.99%
# Epoch 475: train loss = 0.4205, train acc = 88.09%, test acc = 70.02%
# Epoch 476: train loss = 0.4504, train acc = 88.23%, test acc = 69.50%
# Epoch 477: train loss = 0.4455, train acc = 87.71%, test acc = 69.99%
# Epoch 478: train loss = 0.4172, train acc = 87.87%, test acc = 69.65%
# Epoch 479: train loss = 0.4794, train acc = 87.66%, test acc = 69.10%
# Epoch 480: train loss = 0.4878, train acc = 87.82%, test acc = 70.14%
# Epoch 481: train loss = 0.4199, train acc = 88.17%, test acc = 69.91%
# Epoch 482: train loss = 0.4848, train acc = 88.22%, test acc = 69.46%
# Epoch 483: train loss = 0.4311, train acc = 88.20%, test acc = 69.71%
# Epoch 484: train loss = 0.4109, train acc = 88.23%, test acc = 69.23%
# Epoch 485: train loss = 0.4069, train acc = 88.14%, test acc = 69.47%
# Epoch 486: train loss = 0.3630, train acc = 88.23%, test acc = 69.98%
# Epoch 487: train loss = 0.3969, train acc = 88.14%, test acc = 69.47%
# Epoch 488: train loss = 0.4399, train acc = 88.12%, test acc = 69.34%
# Epoch 489: train loss = 0.5010, train acc = 87.89%, test acc = 69.89%
# Epoch 490: train loss = 0.4088, train acc = 88.16%, test acc = 69.44%
# Epoch 491: train loss = 0.4662, train acc = 87.77%, test acc = 69.62%
# Epoch 492: train loss = 0.4306, train acc = 88.14%, test acc = 69.22%
# Epoch 493: train loss = 0.4421, train acc = 88.39%, test acc = 69.95%
# Epoch 494: train loss = 0.4596, train acc = 88.41%, test acc = 69.85%
# Epoch 495: train loss = 0.4334, train acc = 88.42%, test acc = 69.61%
# Epoch 496: train loss = 0.3839, train acc = 88.45%, test acc = 69.56%
# Epoch 497: train loss = 0.4367, train acc = 88.33%, test acc = 69.37%
# Epoch 498: train loss = 0.4227, train acc = 88.31%, test acc = 69.82%
# Epoch 499: train loss = 0.4115, train acc = 88.15%, test acc = 69.77%
# Epoch 500: train loss = 0.4177, train acc = 88.22%, test acc = 70.17%

# %%
# investigate TOP 5 ERROR of the model.
# compare with top 1 error (accuracy)

model.load_state_dict(best_model)
model.eval()

# get predictions for ALL testing data
k = 5
test_pred = model(x_test)
test_pred_top_k = torch.topk(test_pred, k=k, dim=1)[1]

total = 0
in_top_k = 0
for index, value in enumerate(y_test):
    if value in test_pred_top_k[index]: in_top_k += 1

    total += 1

top_k_accuracy = in_top_k * 100 / total

print(f"Top {k} Accuracy: {top_k_accuracy:.03f}%")
# Out:
# Top 5 Accuracy: 83.479%

# %%
folder_df["file"].value_counts()
# Out:
# file
# XC497333.ogg    195
# XC729080.ogg    194
# XC494104.ogg    192
# XC416747.mp3    185
# XC580177.ogg    173
#                ...
# XC388693.mp3      1
# XC304426.ogg      1
# XC210866.mp3      1
# XC193421.mp3      1
# XC476563.ogg      1
# Name: count, Length: 3628, dtype: int64

# %%
accuracy_df = pd.DataFrame(data=[y_test.cpu().numpy(), test_pred_top_k.cpu().numpy()], index=["actual", "pred"]).transpose()
accuracy_df["in_top_5"] = [1 if accuracy_df.iloc[i, 0] in accuracy_df.iloc[i, 1] else 0 for i in range(len(accuracy_df.index))]
folder_top_5 = accuracy_df.groupby(by="actual").aggregate(func=np.sum)["in_top_5"].values
folder_counts = accuracy_df.groupby(by="actual").aggregate(func=np.size)["in_top_5"].values
accuracy_df = pd.DataFrame(data=[folder_top_5, folder_counts], index=["in_top_5", "count"]).transpose()
accuracy_df["top_5_accuracy"] = round(accuracy_df["in_top_5"] * 100 / accuracy_df["count"], 2)
accuracy_df.sort_values(by="top_5_accuracy")
# Out:
#      in_top_5  count  top_5_accuracy
# 149        36     69           52.17
# 169        36     68           52.94
# 93         35     66           53.03
# 115        28     51           54.90
# 91         38     62           61.29
# ..        ...    ...             ...
# 78         66     67           98.51
# 82         72     72          100.00
# 35         69     69          100.00
# 141        70     70          100.00
# 198        64     64          100.00
#
# [200 rows x 3 columns]

# %%
# takes in a whole file as input, feeds into the model, performs sequential aggregation
# gives a single output based on aggregation strategy
def test_file(folder, file_path):
    global sample_rate, split_length, model
    samples = []
    
    # load file data and resample to sample_rate if necessary
    file_data, file_sample_rate_hz = torchaudio.load(uri=file_path, channels_first=True)
    if file_sample_rate_hz != sample_rate:
        file_data = torchaudio.functional.resample(file_data, orig_freq=file_sample_rate_hz, new_freq=sample_rate)

    # convert all audio into mono (1 channel) if audio is stereo (2 channels)
    if file_data.shape[0] == 2: file_data = file_data.mean(dim=0)
    else: file_data = file_data.flatten()

    # get total number of X second splits
    total_splits = floor(len(file_data) / int(sample_rate * split_interval_secs))
    
    # convert file data into mel-spectrogram fourier transform for feeding into CNN
    n_fft = 1024

    mel_spec_transform = torchaudio.transforms.MelSpectrogram(sample_rate = sample_rate, power=2, n_fft=n_fft)
    amp_to_db_transform = torchaudio.transforms.AmplitudeToDB(stype="amplitude", top_db=80)
    mel_spec_data_db = amp_to_db_transform(mel_spec_transform(file_data))
    
    # if file is at least X seconds.
    if total_splits >= 1:
        split_length = min(mel_spec_data_db.shape[1] // total_splits, split_length)
        mel_spec_splits = np.arange(0, mel_spec_data_db.shape[1], split_length)
        for i in range(len(mel_spec_splits) - 1):
            start = mel_spec_splits[i]
            end = mel_spec_splits[i + 1]

            mel_spec_split = mel_spec_data_db[:, start:end]

            # add testing sample to end
            samples.append(mel_spec_split.reshape(1, 128, -1).numpy())
    else:
        return None

    samples = torch.Tensor(np.array(samples)).to(device)

    preds = model(samples)

    '''
    # Ax[classes] sized array, A = number of splits in file
    # sequential aggregation via normalisation + summation (appears to be the best solution right now, but barely by much)
    seq_aggregation_result = torch.sum(nn.functional.normalize(preds, dim=1), dim=0)
    prediction_order = [folder_key[i] for i in torch.topk(seq_aggregation_result, k=len(seq_aggregation_result)).indices.cpu().numpy()]
    location = prediction_order.index(folder) + 1 # because of zero index, adjust to make it 1-indexed
    
    return location, prediction_order
    '''
    
    # sequential aggregation via ranking
    # - assign each folder a rank (using topk) for each prediction, starting from 0 or 1.
    # - sum the ranks over each folder
    # - arrange each rank sum from smallest to largest
    # - smaller sums = higher predictions
    
    folder_ranks = {}
    
    for pred in preds:
        ranks = torch.topk(pred, k=5).indices.cpu().numpy()

        rank_value = 1 # can start at 0 as well. #1 makes sense for "first place"
        for rank in ranks:
            key = folder_key[rank]
            folder_ranks[key] = folder_ranks.get(key, 0) + rank_value

            rank_value += 1

    folder_ranks = dict(sorted(folder_ranks.items(), key=lambda x: x[1]))
    
    location = list(folder_ranks.keys()).index(folder) + 1 if folder in list(folder_ranks.keys()) else 50000

    return location, list(folder_ranks.keys())

# %%
is_valid_file = False

valid_files = valid_files = set([l.replace("\n", "") for l in open(f"rating_thresholds_at_least_10_classes/min_rating_{int(min_rating * 2)}.txt").readlines()])

while not is_valid_file:
    random_folder = "../../datasets/birdsongs-combined/train_audio/" + random.choice([i for i in folder_key.values()]) + "/"
    random_folder = "/mnt/lustre/peprmint/train_audio/" + random.choice([i for i in folder_key.values()]) + "/"
    random_file = random_folder + random.choice(os.listdir(random_folder))

    if random_file.split("/")[-2] + "/" + random_file.split("/")[-1] in valid_files:
        is_valid_file = True

print(random_file)

test_file(random_folder.split("/")[-2], random_file)
# Out:
# /mnt/lustre/peprmint/train_audio/cinfly2/XC131224.ogg
# (50000,
#  ['grewar3',
#   'eurwig',
#   'blkfra',
#   'buwwar',
#   'littin1',
#   'rerswa1',
#   'calqua',
#   'tafpri1',
#   'cobtan1',
#   'yebcha',
#   'compau',
#   'rinkin1',
#   'woothr',
#   'yehcar1',
#   'lesgre1',
#   'warwhe1',
#   'banana',
#   'lotduc',
#   'yebela1',
#   'ccbfin',
#   'whiwre1',
#   'wilsni1',
#   'rucspa1',
#   'whwbec1',
#   'redcro',
#   'wesmea',
#   'bkcbul1',
#   'comkin1',
#   'comfla1'])

# %%
# do above but for EVERY SINGLE FILE in the classes used

base_path = "../../datasets/birdsongs-combined/train_audio/"
base_path = "/mnt/lustre/peprmint/train_audio/"

valid_files = set([l.replace("\n", "") for l in open(f"rating_thresholds_at_least_10_classes/min_rating_{int(min_rating * 2)}.txt").readlines()])
sequential_aggregation_results = {}

for folder in folder_key.values():

    folder_path = base_path + folder + "/"

    folder_length = len(os.listdir(folder_path))
    file_counter = 0
    for file in (progress_bar := tqdm(os.listdir(folder_path))):
        file_counter += 1
        progress_bar.set_description(f"{folder} - {file_counter}/{folder_length}")
        
        file_path = folder_path + file

        if folder + "/" + file in valid_files:
            result = test_file(folder, file_path)
            if result:
                sequential_aggregation_results[folder] = sequential_aggregation_results.get(folder, []) + [result[0]]
# Out:
# dowwoo - 160/160: 100%|██████████| 160/160 [00:01<00:00, 97.68it/s]
# rerswa1 - 256/256: 100%|██████████| 256/256 [00:03<00:00, 71.12it/s]
# cobtan1 - 184/184: 100%|██████████| 184/184 [00:01<00:00, 99.46it/s]
# barswa - 903/903: 100%|██████████| 903/903 [00:17<00:00, 52.97it/s]
# indbun - 207/207: 100%|██████████| 207/207 [00:03<00:00, 58.95it/s]
# comloo - 116/116: 100%|██████████| 116/116 [00:00<00:00, 179.45it/s]
# mitpar - 59/59: 100%|██████████| 59/59 [00:01<00:00, 39.06it/s]
# blhpar1 - 159/159: 100%|██████████| 159/159 [00:01<00:00, 112.02it/s]
# amepip - 118/118: 100%|██████████| 118/118 [00:00<00:00, 140.76it/s]
# brnjay - 66/66: 100%|██████████| 66/66 [00:01<00:00, 48.56it/s]
# sheowl - 129/129: 100%|██████████| 129/129 [00:02<00:00, 59.15it/s]
# peflov - 38/38: 100%|██████████| 38/38 [00:00<00:00, 44.30it/s]
# zebdov - 89/89: 100%|██████████| 89/89 [00:00<00:00, 147.18it/s]
# yehcar1 - 126/126: 100%|██████████| 126/126 [00:02<00:00, 56.98it/s]
# cubthr - 500/500: 100%|██████████| 500/500 [00:03<00:00, 145.27it/s]
# amtspa - 24/91:   0%|          | 0/91 [00:00<?, ?it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# amtspa - 90/91:  79%|███████▉  | 72/91 [00:01<00:00, 86.05it/s] Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# amtspa - 91/91: 100%|██████████| 91/91 [00:01<00:00, 74.22it/s]
# spotow - 287/503:  56%|█████▋    | 283/503 [00:07<00:03, 61.67it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# spotow - 503/503: 100%|██████████| 503/503 [00:12<00:00, 41.65it/s]
# buwwar - 97/97: 100%|██████████| 97/97 [00:03<00:00, 25.80it/s]
# insowl1 - 35/35: 100%|██████████| 35/35 [00:00<00:00, 45.65it/s]
# annhum - 25/127:  17%|█▋        | 21/127 [00:00<00:02, 42.49it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# annhum - 127/127: 100%|██████████| 127/127 [00:01<00:00, 78.63it/s]
# bkskit1 - 268/268: 100%|██████████| 268/268 [00:04<00:00, 53.71it/s]
# bkbmag1 - 72/72: 100%|██████████| 72/72 [00:00<00:00, 74.33it/s]
# litegr - 436/436: 100%|██████████| 436/436 [00:04<00:00, 98.91it/s]
# verdin - 144/144: 100%|██████████| 144/144 [00:02<00:00, 59.02it/s]
# comyel - 401/401: 100%|██████████| 401/401 [00:06<00:00, 59.90it/s]
# brubru1 - 81/81: 100%|██████████| 81/81 [00:00<00:00, 249.22it/s]
/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 26/512:   4%|▍         | 23/512 [00:00<00:11, 43.17it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 98/512:  19%|█▉        | 97/512 [00:03<00:16, 24.72it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 193/512:  37%|███▋      | 188/512 [00:08<00:11, 28.31it/s]Note: Illegal Audio-MPEG-Header 0x6f647974 at offset 58849.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# houwre - 238/512:  45%|████▌     | 232/512 [00:10<00:13, 20.60it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 302/512:  58%|█████▊    | 295/512 [00:12<00:08, 24.80it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 329/512:  63%|██████▎   | 325/512 [00:14<00:11, 16.47it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 433/512:  84%|████████▍ | 431/512 [00:19<00:02, 33.27it/s]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# houwre - 512/512: 100%|██████████| 512/512 [00:22<00:00, 23.09it/s]
# bkwsti - 500/500: 100%|██████████| 500/500 [00:12<00:00, 40.14it/s]
# bkctch1 - 109/109: 100%|██████████| 109/109 [00:00<00:00, 168.65it/s]
# sltnig1 - 33/33: 100%|██████████| 33/33 [00:00<00:00, 49.46it/s]
# burpar - 20/20: 100%|██████████| 20/20 [00:00<00:00, 43.19it/s]
# chispa - 247/247: 100%|██████████| 247/247 [00:05<00:00, 45.30it/s]

# %%
rows = []

for folder in sequential_aggregation_results.keys():
    row = {}

    results = sequential_aggregation_results[folder]

    row["folder"] = folder
    row["total_files"] = len(results)
    row["in_top_1_percentage"] = round(sum([1 if result == 1 else 0 for result in results]) * 100 / len(results), 2)
    row["in_top_5_percentage"] = round(sum([1 if result <= 5 else 0 for result in results]) * 100 / len(results), 2)

    rows.append(row)

sequential_aggregation_df = pd.DataFrame(rows)

sequential_aggregation_df["top_1_product"] = sequential_aggregation_df["total_files"] * sequential_aggregation_df["in_top_1_percentage"]
sequential_aggregation_df["top_5_product"] = sequential_aggregation_df["total_files"] * sequential_aggregation_df["in_top_5_percentage"]

print(sum(sequential_aggregation_df["top_1_product"]) / sum(sequential_aggregation_df["total_files"]))
print(sum(sequential_aggregation_df["top_5_product"]) / sum(sequential_aggregation_df["total_files"]))

sequential_aggregation_df.sort_values(by="in_top_5_percentage", ascending=False)
# Out:
# 0.45119550858652574
# 2.4986525759577276
#       folder  total_files  in_top_1_percentage  in_top_5_percentage  \
# 8     amepip           24                 4.17                16.67
# 20   bkskit1           67                 7.46                16.42
# 112  blsspa1           21                 4.76                14.29
# 81   yebapa1           16                 0.00                12.50
# 124   meapar           40                 5.00                12.50
# ..       ...          ...                  ...                  ...
# 192  sthant1           30                 0.00                 0.00
# 196  bkctch1           15                 0.00                 0.00
# 197  sltnig1           17                 0.00                 0.00
# 198   burpar           12                 0.00                 0.00
# 199   chispa           47                 0.00                 0.00
#
#      top_1_product  top_5_product
# 8           100.08         400.08
# 20          499.82        1100.14
# 112          99.96         300.09
# 81            0.00         200.00
# 124         200.00         500.00
# ..             ...            ...
# 192           0.00           0.00
# 196           0.00           0.00
# 197           0.00           0.00
# 198           0.00           0.00
# 199           0.00           0.00
#
# [200 rows x 6 columns]
