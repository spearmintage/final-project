#  'amecro/XC155441.mp3',
#  'amecro/XC160878.mp3',
#  'amecro/XC160880.mp3',
#  'amecro/XC167792.mp3',
#  'amecro/XC172427.mp3',
#  'amecro/XC172875.mp3',
#  'amecro/XC172878.mp3',
#  'amecro/XC180081.mp3',
#  'amecro/XC181497.mp3',
#  'amecro/XC187481.mp3',
#  'amecro/XC188842.mp3',
#  'amecro/XC191952.mp3',
#  'amecro/XC191954.mp3',
#  'amecro/XC193111.mp3',
#  'amecro/XC193112.mp3',
#  'amecro/XC195540.mp3',
#  'amecro/XC197259.mp3',
#  'amecro/XC197260.mp3',
#  'amecro/XC197261.mp3',
#  'amecro/XC206082.mp3',
#  'amecro/XC233496.mp3',
#  'amecro/XC268481.mp3',
#  'amecro/XC279721.mp3',
#  'amecro/XC279723.mp3',
#  'amecro/XC289011.mp3',
#  'amecro/XC293246.mp3',
#  'amecro/XC293291.mp3',
#  'amecro/XC293812.mp3',
#  'amecro/XC296308.mp3',
#  'amecro/XC309641.mp3',
#  'amecro/XC312752.mp3',
#  'amecro/XC314874.mp3',
#  'amecro/XC315688.mp3',
#  'amecro/XC316302.mp3',
#  'amecro/XC317205.mp3',
#  'amecro/XC318014.mp3',
#  'amecro/XC320383.mp3',
#  'amecro/XC325096.mp3',
#  'amecro/XC325935.mp3',
#  'amecro/XC328542.mp3',
#  'amecro/XC332328.mp3',
#  'amecro/XC333146.mp3',
#  'amecro/XC345874.mp3',
#  'amecro/XC351540.mp3',
#  'amecro/XC361336.mp3',
#  'amecro/XC363862.mp3',
#  'amecro/XC364635.mp3',
#  'amecro/XC371062.mp3',
#  'amecro/XC376180.mp3',
#  'amecro/XC376182.mp3',
#  'amecro/XC381507.mp3',
#  'amecro/XC388685.mp3',
#  'amecro/XC393299.mp3',
#  'amecro/XC413030.mp3',
#  'amecro/XC414021.mp3',
#  'amecro/XC414931.mp3',
#  'amecro/XC424738.mp3',
#  'amecro/XC448753.mp3',
#  'amecro/XC451209.mp3',
#  'amecro/XC454252.mp3',
#  'amecro/XC456644.mp3',
#  'amecro/XC459466.mp3',
#  'amecro/XC460987.mp3',
#  'amecro/XC478839.mp3',
#  'amecro/XC480052.mp3',
#  'amecro/XC481136.mp3',
#  'amecro/XC481933.mp3',
#  'amecro/XC496354.mp3',
#  'amecro/XC496355.mp3',
#  'amecro/XC51410.mp3',
#  'amegfi/XC109299.mp3',
#  'amegfi/XC109300.mp3',
#  'amegfi/XC109301.mp3',
#  'amegfi/XC109606.mp3',
#  'amegfi/XC114087.mp3',
#  'amegfi/XC114342.mp3',
#  'amegfi/XC124312.mp3',
#  'amegfi/XC127600.mp3',
#  'amegfi/XC131637.mp3',
#  'amegfi/XC133564.mp3',
#  'amegfi/XC133565.mp3',
#  'amegfi/XC133569.mp3',
#  'amegfi/XC139798.mp3',
#  'amegfi/XC141469.mp3',
#  'amegfi/XC153552.mp3',
#  'amegfi/XC156788.mp3',
#  'amegfi/XC157457.mp3',
#  'amegfi/XC165034.mp3',
#  'amegfi/XC169080.mp3',
#  'amegfi/XC169081.mp3',
#  'amegfi/XC169082.mp3',
#  'amegfi/XC169083.mp3',
#  'amegfi/XC169084.mp3',
#  'amegfi/XC169085.mp3',
#  'amegfi/XC17120.mp3',
#  'amegfi/XC175254.mp3',
#  'amegfi/XC177152.mp3',
#  'amegfi/XC179074.mp3',
#  'amegfi/XC179086.mp3',
#  'amegfi/XC179092.mp3',
#  'amegfi/XC179124.mp3',
#  'amegfi/XC179304.mp3',
#  'amegfi/XC182073.mp3',
#  'amegfi/XC182078.mp3',
#  'amegfi/XC182406.mp3',
#  'amegfi/XC191980.mp3',
#  'amegfi/XC192078.mp3',
#  'amegfi/XC192099.mp3',
#  'amegfi/XC205514.mp3',
#  'amegfi/XC206070.mp3',
#  'amegfi/XC210732.mp3',
#  'amegfi/XC210744.mp3',
#  'amegfi/XC210746.mp3',
#  'amegfi/XC210754.mp3',
#  'amegfi/XC217005.mp3',
#  'amegfi/XC236563.mp3',
#  'amegfi/XC239645.mp3',
#  'amegfi/XC253704.mp3',
#  'amegfi/XC255471.mp3',
#  'amegfi/XC276993.mp3',
#  'amegfi/XC288983.mp3',
#  'amegfi/XC288984.mp3',
#  'amegfi/XC294256.mp3',
#  'amegfi/XC294424.mp3',
#  'amegfi/XC298362.mp3',
#  'amegfi/XC31023.mp3',
#  'amegfi/XC313463.mp3',
#  'amegfi/XC313678.mp3',
#  'amegfi/XC313679.mp3',
#  'amegfi/XC313680.mp3',
#  'amegfi/XC313681.mp3',
#  'amegfi/XC315299.mp3',
#  'amegfi/XC315598.mp3',
#  'amegfi/XC318488.mp3',
#  'amegfi/XC323308.mp3',
#  'amegfi/XC324344.mp3',
#  'amegfi/XC325098.mp3',
#  'amegfi/XC325659.mp3',
#  'amegfi/XC327670.mp3',
#  'amegfi/XC333998.mp3',
#  'amegfi/XC344965.mp3',
#  'amegfi/XC363216.mp3',
#  'amegfi/XC367697.mp3',
#  'amegfi/XC368590.mp3',
#  'amegfi/XC372211.mp3',
#  'amegfi/XC382506.mp3',
#  'amegfi/XC383905.mp3',
#  'amegfi/XC383960.mp3',
#  'amegfi/XC385206.mp3',
#  'amegfi/XC388255.mp3',
#  'amegfi/XC389252.mp3',
#  'amegfi/XC390608.mp3',
#  'amegfi/XC394110.mp3',
#  'amegfi/XC411318.mp3',
#  'amegfi/XC420842.mp3',
#  'amegfi/XC428425.mp3',
#  'amegfi/XC429266.mp3',
#  'amegfi/XC437593.mp3',
#  'amegfi/XC453934.mp3',
#  'amegfi/XC454621.mp3',
#  'amegfi/XC462056.mp3',
#  'amegfi/XC476270.mp3',
#  'amegfi/XC483030.mp3',
#  'amegfi/XC486563.mp3',
#  'amegfi/XC493543.mp3',
#  'amegfi/XC496109.mp3',
#  'amegfi/XC502629.mp3',
#  'amegfi/XC504150.mp3',
#  'amegfi/XC51411.mp3',
#  'amekes/XC114061.mp3',
#  'amekes/XC127418.mp3',
#  'amekes/XC133392.mp3',
#  'amekes/XC138718.mp3',
#  'amekes/XC147272.mp3',
#  'amekes/XC147273.mp3',
#  'amekes/XC160904.mp3',
#  'amekes/XC16111.mp3',
#  'amekes/XC213165.mp3',
#  'amekes/XC214256.mp3',
#  'amekes/XC214257.mp3',
#  'amekes/XC214259.mp3',
#  'amekes/XC216657.mp3',
#  'amekes/XC238264.mp3',
#  'amekes/XC250844.mp3',
#  'amekes/XC253328.mp3',
#  'amekes/XC253935.mp3',
#  'amekes/XC253951.mp3',
#  'amekes/XC254588.mp3',
#  'amekes/XC254589.mp3',
#  'amekes/XC257401.mp3',
#  'amekes/XC267262.mp3',
#  'amekes/XC278000.mp3',
#  'amekes/XC289032.mp3',
#  'amekes/XC289663.mp3',
#  'amekes/XC297550.mp3',
#  'amekes/XC298663.mp3',
#  'amekes/XC304798.mp3',
#  'amekes/XC308302.mp3',
#  'amekes/XC341005.mp3',
#  'amekes/XC348428.mp3',
#  'amekes/XC362105.mp3',
#  'amekes/XC362208.mp3',
#  'amekes/XC375505.mp3',
#  'amekes/XC391843.mp3',
#  'amekes/XC399014.mp3',
#  'amekes/XC416142.mp3',
#  'amekes/XC418510.mp3',
#  'amekes/XC418891.mp3',
#  'amekes/XC418893.mp3',
#  'amekes/XC419402.mp3',
#  'amekes/XC420472.mp3',
#  'amekes/XC420473.mp3',
#  'amekes/XC426297.mp3',
#  'amekes/XC426298.mp3',
#  'amekes/XC431030.mp3',
#  'amekes/XC431032.mp3',
#  'amekes/XC432334.mp3',
#  'amekes/XC438159.mp3',
#  'amekes/XC443522.mp3',
#  'amekes/XC443812.mp3',
#  'amekes/XC449552.mp3',
#  'amekes/XC451207.mp3',
#  'amekes/XC466164.mp3',
#  'amekes/XC466166.mp3',
#  'amekes/XC466449.mp3',
#  'amekes/XC473676.mp3',
#  'amekes/XC482875.mp3',
#  'amekes/XC483212.mp3',
#  'amekes/XC51475.mp3',
#  'amekes/XC56416.mp3',
#  'amekes/XC59480.mp3',
#  'amepip/XC111040.mp3',
#  'amepip/XC111041.mp3',
#  'amepip/XC111042.mp3',
#  'amepip/XC111043.mp3',
#  'amepip/XC113721.mp3',
#  'amepip/XC113723.mp3',
#  'amepip/XC113724.mp3',
#  'amepip/XC135087.mp3',
#  'amepip/XC144540.mp3',
#  'amepip/XC151283.mp3',
#  'amepip/XC153409.mp3',
#  'amepip/XC153410.mp3',
#  'amepip/XC153411.mp3',
#  'amepip/XC153412.mp3',
#  'amepip/XC157677.mp3',
#  'amepip/XC157890.mp3',
#  'amepip/XC179713.mp3',
#  'amepip/XC188038.mp3',
#  'amepip/XC202805.mp3',
#  'amepip/XC202806.mp3',
#  'amepip/XC202807.mp3',
#  'amepip/XC202808.mp3',
#  'amepip/XC203607.mp3',
#  'amepip/XC203608.mp3',
#  'amepip/XC206155.mp3',
#  'amepip/XC206516.mp3',
#  'amepip/XC210758.mp3',
#  'amepip/XC210759.mp3',
#  'amepip/XC210760.mp3',
#  'amepip/XC212144.mp3',
#  'amepip/XC267501.mp3',
#  'amepip/XC267502.mp3',
#  'amepip/XC277505.mp3',
#  'amepip/XC277506.mp3',
#  'amepip/XC277508.mp3',
#  'amepip/XC277511.mp3',
#  'amepip/XC277523.mp3',
#  'amepip/XC277550.mp3',
#  'amepip/XC277553.mp3',
#  'amepip/XC277562.mp3',
#  'amepip/XC277579.mp3',
#  'amepip/XC277582.mp3',
#  'amepip/XC277586.mp3',
#  'amepip/XC277590.mp3',
#  'amepip/XC277600.mp3',
#  'amepip/XC277601.mp3',
#  'amepip/XC277602.mp3',
#  'amepip/XC277603.mp3',
#  'amepip/XC277604.mp3',
#  'amepip/XC277605.mp3',
#  'amepip/XC277637.mp3',
#  'amepip/XC277676.mp3',
#  'amepip/XC277679.mp3',
#  'amepip/XC287461.mp3',
#  'amepip/XC291092.mp3',
#  'amepip/XC306144.mp3',
#  'amepip/XC325263.mp3',
#  'amepip/XC327648.mp3',
#  'amepip/XC333905.mp3',
#  'amepip/XC338292.mp3',
#  'amepip/XC339906.mp3',
#  'amepip/XC341450.mp3',
#  'amepip/XC342803.mp3',
#  'amepip/XC358830.mp3',
#  'amepip/XC358842.mp3',
#  'amepip/XC358862.mp3',
#  'amepip/XC382376.mp3',
#  'amepip/XC431957.mp3',
#  'amepip/XC433231.mp3',
#  'amepip/XC437043.mp3',
#  'amepip/XC438455.mp3',
#  'amepip/XC441362.mp3',
#  'amepip/XC448720.mp3',
#  'amepip/XC448945.mp3',
#  'amepip/XC452806.mp3',
#  'amepip/XC452810.mp3',
#  'amepip/XC452814.mp3',
#  'amepip/XC452816.mp3',
#  'amepip/XC464205.mp3',
#  'amepip/XC51412.mp3',
#  'amered/XC101593.mp3',
#  'amered/XC125512.mp3',
#  'amered/XC133902.mp3',
#  'amered/XC134496.mp3',
#  'amered/XC134499.mp3',
#  'amered/XC135440.mp3',
#  'amered/XC135462.mp3',
#  'amered/XC135463.mp3',
#  'amered/XC135466.mp3',
#  'amered/XC135468.mp3',
#  'amered/XC137604.mp3',
#  'amered/XC137610.mp3',
#  'amered/XC139433.mp3',
#  'amered/XC139439.mp3',
#  'amered/XC139880.mp3',
#  'amered/XC139937.mp3',
#  'amered/XC139938.mp3',
#  'amered/XC142592.mp3',
#  'amered/XC144666.mp3',
#  'amered/XC149269.mp3',
#  'amered/XC167793.mp3',
#  'amered/XC177037.mp3',
#  'amered/XC178129.mp3',
#  'amered/XC178310.mp3',
#  'amered/XC179185.mp3',
#  'amered/XC179188.mp3',
#  'amered/XC179305.mp3',
#  'amered/XC179362.mp3',
#  'amered/XC179630.mp3',
#  'amered/XC179661.mp3',
#  'amered/XC183621.mp3',
#  'amered/XC186306.mp3',
#  'amered/XC187608.mp3',
#  'amered/XC187609.mp3',
#  'amered/XC187783.mp3',
#  'amered/XC188493.mp3',
#  'amered/XC188494.mp3',
#  'amered/XC188495.mp3',
#  'amered/XC193127.mp3',
#  'amered/XC193128.mp3',
#  'amered/XC193130.mp3',
#  'amered/XC193134.mp3',
#  'amered/XC193769.mp3',
#  'amered/XC195834.mp3',
#  'amered/XC195835.mp3',
#  'amerob/XC338199.mp3',
#  'amerob/XC366599.mp3',
#  'amerob/XC367008.mp3',
#  'amerob/XC368614.mp3',
#  'amerob/XC368615.mp3',
#  'amerob/XC375006.mp3',
#  'amerob/XC381535.mp3',
#  'amerob/XC381579.mp3',
#  'amerob/XC383961.mp3',
#  'amerob/XC384027.mp3',
#  'amerob/XC385843.mp3',
#  'amerob/XC394835.mp3',
#  'amerob/XC396272.mp3',
#  'amerob/XC406326.mp3',
#  'amerob/XC407819.mp3',
#  'amerob/XC409609.mp3',
#  'amerob/XC416294.mp3',
#  'amerob/XC422421.mp3',
#  'amerob/XC423449.mp3',
#  'amerob/XC424786.mp3',
#  'amerob/XC446457.mp3',
#  'amerob/XC446458.mp3',
#  'amerob/XC446460.mp3',
#  'amerob/XC446462.mp3',
#  'amerob/XC448274.mp3',
#  'amerob/XC451211.mp3',
#  'amerob/XC452609.mp3',
#  'amerob/XC464670.mp3',
#  'amerob/XC464766.mp3',
#  'amerob/XC464997.mp3',
#  'amerob/XC464999.mp3',
#  'amerob/XC465001.mp3',
#  'amerob/XC466048.mp3',
#  'amerob/XC466479.mp3',
#  'amerob/XC468243.mp3',
#  'amerob/XC468991.mp3',
#  'amerob/XC469605.mp3',
#  'amerob/XC474615.mp3',
#  'amerob/XC476494.mp3',
#  'amerob/XC476496.mp3',
#  'amerob/XC480682.mp3',
#  'amerob/XC480926.mp3',
#  'amerob/XC482331.mp3',
#  'amerob/XC483578.mp3',
#  'amerob/XC483628.mp3',
#  'amerob/XC483875.mp3',
#  'amerob/XC495411.mp3',
#  'amerob/XC504196.mp3',
#  'amewig/XC150015.mp3',
#  'amewig/XC150063.mp3',
#  'amewig/XC152348.mp3',
#  'amewig/XC152396.mp3',
#  'amewig/XC152873.mp3',
#  'amewig/XC153020.mp3',
#  'amewig/XC165450.mp3',
#  'amewig/XC172886.mp3',
#  'amewig/XC172887.mp3',
#  'amewig/XC172888.mp3',
#  'amewig/XC172889.mp3',
#  'amewig/XC172890.mp3',
#  'amewig/XC187408.mp3',
#  'amewig/XC187411.mp3',
#  'amewig/XC293789.mp3',
#  'amewig/XC298401.mp3',
#  'amewig/XC301850.mp3',
#  'amewig/XC305019.mp3',
#  'amewig/XC305020.mp3',
#  'amewig/XC305022.mp3',
#  'amewig/XC305023.mp3',
#  'amewig/XC305276.mp3',
#  'amewig/XC309315.mp3',
#  'amewig/XC335125.mp3',
#  'amewig/XC335126.mp3',
#  'amewig/XC379016.mp3',
#  'amewig/XC384955.mp3',
#  'amewig/XC396690.mp3',
#  'amewig/XC398300.mp3',
#  'amewig/XC403005.mp3',
#  'amewig/XC404504.mp3',
#  'amewig/XC448935.mp3',
#  'amewig/XC448937.mp3',
#  'amtspa/XC115430.mp3',
#  'amtspa/XC115594.mp3',
#  'amtspa/XC121042.mp3',
#  'amtspa/XC127999.mp3',
#  'amtspa/XC128001.mp3',
#  'amtspa/XC128002.mp3',
#  'amtspa/XC128099.mp3',
#  'amtspa/XC128705.mp3',
#  'annhum/XC157666.mp3',
#  'annhum/XC160906.mp3',
#  'annhum/XC160907.mp3',
#  'annhum/XC160908.mp3',
#  'annhum/XC160910.mp3',
#  'annhum/XC160911.mp3',
#  'annhum/XC160912.mp3',
#  'annhum/XC160913.mp3',
#  'annhum/XC160914.mp3',
#  'annhum/XC169596.mp3',
#  'annhum/XC169597.mp3',
#  'annhum/XC173184.mp3',
#  'annhum/XC183580.mp3',
#  'annhum/XC196545.mp3',
#  'annhum/XC196689.mp3',
#  'annhum/XC196691.mp3',
#  'annhum/XC198054.mp3',
#  'annhum/XC198499.mp3',
#  'annhum/XC209320.mp3',
#  'annhum/XC216179.mp3',
#  'annhum/XC282320.mp3',
#  'annhum/XC289049.mp3',
#  'annhum/XC292274.mp3',
#  'annhum/XC292588.mp3',
#  'annhum/XC296918.mp3',
#  'annhum/XC297296.mp3',
#  'annhum/XC297440.mp3',
#  'annhum/XC297468.mp3',
#  'annhum/XC328180.mp3',
#  'annhum/XC348361.mp3',
#  'annhum/XC348985.mp3',
#  'annhum/XC350764.mp3',
#  'annhum/XC354737.mp3',
#  'annhum/XC362401.mp3',
#  'annhum/XC367257.mp3',
#  'annhum/XC373783.mp3',
#  'annhum/XC400968.mp3',
#  'annhum/XC406522.mp3',
#  'annhum/XC406526.mp3',
#  'annhum/XC442358.mp3',
#  'annhum/XC442359.mp3',
#  'annhum/XC448778.mp3',
#  'annhum/XC449497.mp3',
#  'annhum/XC451239.mp3',
#  'annhum/XC451240.mp3',
#  'annhum/XC452505.mp3',
#  'annhum/XC452540.mp3',
#  'annhum/XC453109.mp3',
#  'annhum/XC457444.mp3',
#  'annhum/XC461240.mp3',
#  'annhum/XC462768.mp3',
#  'annhum/XC462769.mp3',
#  'annhum/XC462770.mp3',
#  'annhum/XC462771.mp3',
#  'annhum/XC465010.mp3',
#  'annhum/XC469881.mp3',
#  'annhum/XC473410.mp3',
#  'annhum/XC473411.mp3',
#  'annhum/XC479795.mp3',
#  'annhum/XC493268.mp3',
#  'annhum/XC493338.mp3',
#  'annhum/XC501895.mp3',
#  'annhum/XC57970.mp3',
#  'annhum/XC57971.mp3',
#  'astfly/XC109920.mp3',
#  'astfly/XC109921.mp3',
#  'astfly/XC109922.mp3',
#  'astfly/XC109923.mp3',
#  'astfly/XC122455.mp3',
#  'astfly/XC122806.mp3',
#  'astfly/XC122807.mp3',
#  'astfly/XC122809.mp3',
#  'astfly/XC122810.mp3',
#  'astfly/XC122811.mp3',
#  'astfly/XC122812.mp3',
#  'astfly/XC122813.mp3',
#  'astfly/XC122814.mp3',
#  'astfly/XC122815.mp3',
#  'astfly/XC122816.mp3',
#  'astfly/XC122817.mp3',
#  'astfly/XC122818.mp3',
#  'astfly/XC122819.mp3',
#  'astfly/XC122820.mp3',
#  'astfly/XC122821.mp3',
#  'astfly/XC122822.mp3',
#  'astfly/XC122824.mp3',
#  'astfly/XC122825.mp3',
#  'astfly/XC122826.mp3',
#  'astfly/XC122892.mp3',
#  'astfly/XC122895.mp3',
#  'astfly/XC122896.mp3',
#  'astfly/XC122898.mp3',
#  'astfly/XC122900.mp3',
#  'astfly/XC122904.mp3',
#  'astfly/XC122908.mp3',
#  'astfly/XC122909.mp3',
#  'astfly/XC122910.mp3',
#  'astfly/XC122911.mp3',
#  'astfly/XC122912.mp3',
#  'astfly/XC122913.mp3',
#  'astfly/XC122914.mp3',
#  'astfly/XC122915.mp3',
#  'astfly/XC122916.mp3',
#  'astfly/XC122918.mp3',
#  'astfly/XC122922.mp3',
#  'astfly/XC122924.mp3',
#  'astfly/XC124590.mp3',
#  'astfly/XC124591.mp3',
#  'astfly/XC124593.mp3',
#  'astfly/XC124595.mp3',
#  'astfly/XC141344.mp3',
#  'astfly/XC141345.mp3',
#  'astfly/XC158401.mp3',
#  'astfly/XC163942.mp3',
#  'astfly/XC170238.mp3',
#  'astfly/XC170239.mp3',
#  'astfly/XC170393.mp3',
#  'astfly/XC170415.mp3',
#  'astfly/XC172656.mp3',
#  'astfly/XC178528.mp3',
#  'astfly/XC181474.mp3',
#  'astfly/XC184993.mp3',
#  'astfly/XC185157.mp3',
#  'astfly/XC205473.mp3',
#  'astfly/XC235054.mp3',
#  'astfly/XC244505.mp3',
#  'astfly/XC268646.mp3',
#  'astfly/XC268648.mp3',
#  'astfly/XC268649.mp3',
#  'astfly/XC268655.mp3',
#  'astfly/XC268658.mp3',
#  'astfly/XC268659.mp3',
#  'astfly/XC277243.mp3',
#  'astfly/XC283475.mp3',
#  'astfly/XC283538.mp3',
#  'astfly/XC283540.mp3',
#  'astfly/XC286838.mp3',
#  'astfly/XC292765.mp3',
#  'astfly/XC302540.mp3',
#  'astfly/XC302542.mp3',
#  'astfly/XC308580.mp3',
#  'astfly/XC316162.mp3',
#  'astfly/XC318365.mp3',
#  'astfly/XC324272.mp3',
#  'astfly/XC365936.mp3',
#  'astfly/XC368291.mp3',
#  'astfly/XC376284.mp3',
#  'astfly/XC377114.mp3',
#  'astfly/XC404715.mp3',
#  'astfly/XC417737.mp3',
#  'astfly/XC418344.mp3',
#  'astfly/XC419831.mp3',
#  'astfly/XC425505.mp3',
#  'astfly/XC442320.mp3',
#  'astfly/XC442321.mp3',
#  'astfly/XC450683.mp3',
#  'astfly/XC460579.mp3',
#  'astfly/XC460588.mp3',
#  'astfly/XC482515.mp3',
#  'astfly/XC482868.mp3',
#  'astfly/XC483020.mp3',
#  'astfly/XC483021.mp3',
#  'astfly/XC494351.mp3',
#  'baleag/XC141749.mp3',
#  'baleag/XC149270.mp3',
#  'baleag/XC149271.mp3',
#  'baleag/XC149275.mp3',
#  'baleag/XC149276.mp3',
#  'baleag/XC149277.mp3',
#  'baleag/XC150215.mp3',
#  'baleag/XC150216.mp3',
#  'baleag/XC160915.mp3',
#  'baleag/XC165314.mp3',
#  'baleag/XC177185.mp3',
#  'baleag/XC191961.mp3',
#  'baleag/XC192236.mp3',
#  'baleag/XC192248.mp3',
#  'baleag/XC205515.mp3',
#  'baleag/XC205516.mp3',
#  'baleag/XC209321.mp3',
#  'baleag/XC288994.mp3',
#  'baleag/XC293803.mp3',
#  'baleag/XC324581.mp3',
#  'baleag/XC328715.mp3',
#  'baleag/XC344281.mp3',
#  'baleag/XC344282.mp3',
#  'baleag/XC408110.mp3',
#  'baleag/XC440639.mp3',
#  'baleag/XC446803.mp3',
#  'baleag/XC451490.mp3',
#  'baleag/XC451810.mp3',
#  'baleag/XC499561.mp3',
#  'baleag/XC51757.mp3',
#  'balori/XC101614.mp3',
#  'balori/XC134872.mp3',
#  'balori/XC139089.mp3',
#  'balori/XC139729.mp3',
#  'balori/XC153554.mp3',
#  'balori/XC153556.mp3',
#  'balori/XC153786.mp3',
#  'balori/XC16971.mp3',
#  'balori/XC175541.mp3',
#  'balori/XC175542.mp3',
#  'balori/XC175543.mp3',
#  'balori/XC178046.mp3',
#  'balori/XC179064.mp3',
#  'balori/XC179631.mp3',
#  'balori/XC181121.mp3',
#  'balori/XC182674.mp3',
#  'balori/XC182675.mp3',
#  'balori/XC184648.mp3',
#  'balori/XC185568.mp3',
#  'balori/XC185570.mp3',
#  'balori/XC199663.mp3',
#  'balori/XC216100.mp3',
#  ...]

# %%
train_audio_directory = "/mnt/lustre/peprmint/train_audio/"

# %%
os.listdir(train_audio_directory)
# Out:
# 992

# %%
import os

# attempts to delete every file from files_to_delete
# if the file cannot be found, it skips it
# if the file can be found, it deletes it

#for file in files_to_delete:

files_not_found = 0
files_deleted = 0

for file in files_to_delete:
    file_path = train_audio_directory + file

    try:
        os.remove(file_path)
        files_deleted += 1
    except OSError:
        files_not_found += 1
        pass

print(f"Out of the {len(files_to_delete)} files to delete, {files_deleted} were deleted. {files_not_found} file{'s' if files_not_found != 1 else ''} could not be found.")
# Out:
# Out of the 15874 files to delete, 15874 were deleted. 0 files could not be found.

# %%
# verify no duplicate XC ids are in the dataset

# %%
folders = os.listdir(train_audio_directory)

files = []
for folder in folders:
    files += [file for file in os.listdir(train_audio_directory + folder)]

all_ids = len(files)
unique_ids = len(set(files))

# %%
if all_ids == unique_ids:
    print("All duplicates removed and handled already.")
else:
    print(f"{all_ids - unique_ids} files are duplicates.")

    files = sorted(files)
    duplicate_files = []

    for i in range(len(files) - 1):
        j = i + 1

        if files[i] == files[j]:
            if files[i] not in duplicate_files:
                duplicate_files.append(files[i])

    for duplicate_file in duplicate_files:
        # identify the folder(s) the duplicate appears in.
        duplicates = []

        for folder in folders:
            folder_files = os.listdir(train_audio_directory + folder)

            if duplicate_file in folder_files:
                full_file_path = train_audio_directory + folder + "/" + duplicate_file

                date_modified = os.path.getmtime(full_file_path)
                duplicates.append([full_file_path, date_modified])

        duplicates = sorted(duplicates, key=lambda x: x[1], reverse=True)

        print(f"{duplicate_file}:    The newest file is {duplicates[0][0]}, thus all other files will be deleted.")

        duplicate_files_to_delete = duplicates[1:]

        for duplicate_file_to_delete in duplicate_files_to_delete:
            try:
                os.remove(duplicate_file_to_delete[0])
                print(duplicate_file_to_delete[0], "deleted.")
            except OSError:
                pass

print(f"{unique_ids}/112861 expected files exist in the directory.")
# Out:
# 24 files are duplicates.
# XC163901.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/goflea1/XC163901.ogg, thus all other files will be deleted.
# XC184466.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/woosan/XC184466.ogg, thus all other files will be deleted.
# XC208794.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/goflea1/XC208794.ogg, thus all other files will be deleted.
# XC208795.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/goflea1/XC208795.ogg, thus all other files will be deleted.
# XC209203.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/goflea1/XC209203.ogg, thus all other files will be deleted.
# XC209549.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/goflea1/XC209549.ogg, thus all other files will be deleted.
# XC209564.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/goflea1/XC209564.ogg, thus all other files will be deleted.
# XC239509.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/whbwoo2/XC239509.ogg, thus all other files will be deleted.
# XC294370.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/brant/XC294370.ogg, thus all other files will be deleted.
# XC306398.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/rewbul/XC306398.ogg, thus all other files will be deleted.
# XC316684.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/gnbcam2/XC316684.ogg, thus all other files will be deleted.
# XC403621.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/bcnher/XC403621.ogg, thus all other files will be deleted.
# XC447036.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/labcro1/XC447036.ogg, thus all other files will be deleted.
# XC467373.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/purher1/XC467373.ogg, thus all other files will be deleted.
# XC477595.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/carwre/XC477595.ogg, thus all other files will be deleted.
# XC501149.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/mallar3/XC501149.ogg, thus all other files will be deleted.
# XC503389.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/whtkin2/XC503389.ogg, thus all other files will be deleted.
# XC514027.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/eucdov/XC514027.ogg, thus all other files will be deleted.
# XC522123.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/sbeowl1/XC522123.ogg, thus all other files will be deleted.
# XC574864.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/putbab1/XC574864.ogg, thus all other files will be deleted.
# XC581045.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/wemhar1/XC581045.ogg, thus all other files will be deleted.
# XC590213.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/bkbplo/XC590213.ogg, thus all other files will be deleted.
# XC659329.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/whcbar1/XC659329.ogg, thus all other files will be deleted.
# XC674522.ogg:    The newest file is /mnt/lustre/peprmint/train_audio/litspi1/XC674522.ogg, thus all other files will be deleted.
# 112861/112861 expected files exist in the directory.
