# %% [markdown]
# this file determines out of the 1014 identified species, where are the 22 missing folders in the train_audio folder.

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import os
import pandas as pd

# %%
train_audio_path = "train_audio/"

folder_sheet = pd.read_excel("metadata/final_metadata.xlsx", "FOLDER_SPECIES_TABLE")[["UNIQUE TEXT", "Unnamed: 7"]].iloc[1:1015, :]
folder_sheet.columns = ["folder_code", "species"]
folder_sheet
# Out:
#      folder_code                      species
# 1        abythr1            Abyssinian Thrush
# 2         acafly           Acadian Flycatcher
# 3         acowoo             Acorn Woodpecker
# 4        abethr1     African Bare-eyed Thrush
# 5        abhori1  African Black-headed Oriole
# ...          ...                          ...
# 1010      yetvir        Yellow-throated Vireo
# 1011     yewgre1    Yellow-whiskered Greenbul
# 1012      zebdov                   Zebra Dove
# 1013      madpet                Zino's Petrel
# 1014     zitcis1            Zitting Cisticola
#
# [1014 rows x 2 columns]

# %%
try:
    folders = os.listdir(train_audio_path)
except:
    folders = []
folders
# Out:
# []

# %%
# determines which species of the 1014 are not present in the train_audio directory.

for folder in folder_sheet["folder_code"]:
    if folder not in folders:
        print(folder, "not in train_audio folder.")
# Out:
# abythr1 not in train_audio folder.
# acafly not in train_audio folder.
# acowoo not in train_audio folder.
# abethr1 not in train_audio folder.
# abhori1 not in train_audio folder.
# afbfly1 not in train_audio folder.
# darter3 not in train_audio folder.
# afdfly1 not in train_audio folder.
# afecuc1 not in train_audio folder.
# affeag1 not in train_audio folder.
# afrgos1 not in train_audio folder.
# afgfly1 not in train_audio folder.
# afghor1 not in train_audio folder.
# afrgrp1 not in train_audio folder.
# afrjac1 not in train_audio folder.
# afpfly1 not in train_audio folder.
# afpwag1 not in train_audio folder.
# afpkin1 not in train_audio folder.
# sacibi2 not in train_audio folder.
# afrsil1 not in train_audio folder.
# afrthr1 not in train_audio folder.
# akekee not in train_audio folder.
# akiapo not in train_audio folder.
# akikik not in train_audio folder.
# crehon not in train_audio folder.
# aldfly not in train_audio folder.
# ameavo not in train_audio folder.
# ...
